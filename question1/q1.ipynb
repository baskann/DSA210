# %%
# [Cell 1] - Import required libraries
import pandas as pd
import json
import matplotlib.pyplot as plt
import seaborn as sns
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import time
from datetime import datetime
import numpy as np

# %%
# [Cell 2] - Load and process Spotify data with genres
def get_track_genres(sp, track_name, artist_name):
    """
    Get genre information for a track using Spotify API with error handling
    """
    try:
        # Search for the track
        results = sp.search(q=f"track:{track_name} artist:{artist_name}", type='track', limit=1)
        
        if not results['tracks']['items']:
            return []
        
        # Get artist ID
        artist_id = results['tracks']['items'][0]['artists'][0]['id']
        
        # Get artist details including genres
        artist = sp.artist(artist_id)
        return artist['genres']
    
    except Exception as e:
        print(f"Error getting genres for {track_name} by {artist_name}: {str(e)}")
        return []

def process_spotify_data(client_id, client_secret):
    """
    Process Spotify data with API calls and error handling
    """
    # Initialize Spotify client
    client_credentials_manager = SpotifyClientCredentials(
        client_id=client_id,
        client_secret=client_secret
    )
    sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
    
    # Read streaming history
    with open('StreamingHistory_music_2.json', 'r', encoding='utf-8') as f:
        spotify_data = json.load(f)
    
    # Convert to DataFrame
    df = pd.DataFrame(spotify_data)
    
    # Get unique artist-track combinations
    unique_tracks = df[['artistName', 'trackName']].drop_duplicates()
    
    # Process tracks in batches with delay to avoid timeout
    batch_size = 10
    processed_tracks = []
    
    for i in range(0, len(unique_tracks), batch_size):
        batch = unique_tracks.iloc[i:i+batch_size]
        
        for _, row in batch.iterrows():
            genres = get_track_genres(sp, row['trackName'], row['artistName'])
            processed_tracks.append({
                'artist': row['artistName'],
                'track': row['trackName'],
                'genres': genres
            })
        
        # Add delay between batches
        time.sleep(1)
    
    # Create genre mapping dictionary
    genre_mapping = {
        (track['artist'], track['track']): track['genres']
        for track in processed_tracks
    }
    
    # Add genres to original DataFrame
    df['date'] = pd.to_datetime(df['endTime']).dt.date
    df['genres'] = df.apply(lambda row: genre_mapping.get((row['artistName'], row['trackName']), []), axis=1)
    
    return df

# %%
# [Cell 3] - Process spending data
def get_spending_data():
    """
    Read and process bank transaction data
    """
    bank_df = pd.read_excel('HesapHareketleri_28.11.2024_0124383 (1).xlsx', 
                           skiprows=8,
                           names=['Date', 'Time', 'Amount', 'Balance', 'Description', 'Receipt'])
    
    bank_df = bank_df[bank_df['Date'].str.match(r'\d{2}\.\d{2}\.\d{4}', na=False)]
    bank_df['date'] = pd.to_datetime(bank_df['Date'], format='%d.%m.%Y').dt.date
    bank_df['Amount'] = pd.to_numeric(bank_df['Amount'], errors='coerce')
    
    daily_spending = bank_df.groupby('date')['Amount'].sum().reset_index()
    return daily_spending

# %%
# [Cell 4] - Analyze genre-spending relationships
def analyze_genre_spending(spotify_df, spending_df):
    """
    Analyze relationship between genres and spending
    """
    # Explode genres list to get one row per genre
    genre_df = spotify_df.explode('genres')
    genre_df = genre_df.rename(columns={'genres': 'genre'})
    
    # Remove rows where genre is None
    genre_df = genre_df.dropna(subset=['genre'])
    
    # Calculate daily listening time per genre
    genre_daily = genre_df.groupby(['date', 'genre'])['msPlayed'].sum().reset_index()
    genre_daily['minutes_played'] = genre_daily['msPlayed'] / (1000 * 60)
    
    # Merge with spending data
    merged_df = pd.merge(genre_daily, spending_df, on='date', how='inner')
    
    # Calculate statistics for each genre
    genre_stats = []
    min_days = 5  # Minimum number of days to consider
    
    for genre in merged_df['genre'].unique():
        genre_data = merged_df[merged_df['genre'] == genre]
        if len(genre_data) >= min_days:
            correlation = genre_data['minutes_played'].corr(genre_data['Amount'])
            avg_spending = genre_data['Amount'].mean()
            
            genre_stats.append({
                'genre': genre,
                'correlation': correlation,
                'total_minutes': genre_data['minutes_played'].sum(),
                'avg_spending': avg_spending,
                'days_listened': len(genre_data)
            })
    
    return pd.DataFrame(genre_stats)

# %%
# [Cell 5] - Create visualizations
def create_visualizations(genre_stats_df):
    """
    Create genre analysis visualizations
    """
    # Sort by absolute correlation
    genre_stats_df['abs_correlation'] = abs(genre_stats_df['correlation'])
    genre_stats_df = genre_stats_df.sort_values('abs_correlation', ascending=False)
    
    # Select top genres by listening time
    top_genres = genre_stats_df.nlargest(10, 'total_minutes')
    
    # Create figure
    plt.style.use('default')
    fig, axes = plt.subplots(2, 1, figsize=(12, 12))
    
    # Plot 1: Correlations
    sns.barplot(data=top_genres,
                x='correlation',
                y='genre',
                ax=axes[0])
    axes[0].set_title('Top 10 Genre-Spending Correlations')
    axes[0].set_xlabel('Correlation Coefficient')
    axes[0].axvline(x=0, color='black', linestyle='-', alpha=0.2)
    
    # Plot 2: Average spending by genre
    sns.barplot(data=top_genres,
                x='avg_spending',
                y='genre',
                ax=axes[1])
    axes[1].set_title('Average Daily Spending by Genre')
    axes[1].set_xlabel('Average Spending (TL)')
    
    plt.tight_layout()
    return fig

# %%
# [Cell 2] - Load and process Spotify data with genres
def get_track_genres(sp, track_name, artist_name):
    """
    Get genre information for a track using Spotify API with error handling
    """
    try:
        # Search for the track
        results = sp.search(q=f"track:{track_name} artist:{artist_name}", type='track', limit=1)
        
        if not results['tracks']['items']:
            print(f"No results found for {track_name} by {artist_name}")
            return None
        
        # Get artist ID
        artist_id = results['tracks']['items'][0]['artists'][0]['id']
        
        # Get artist details including genres
        artist = sp.artist(artist_id)
        print(f"Found genres for {artist_name}: {artist['genres']}")
        return artist['genres']
    
    except Exception as e:
        print(f"Error getting genres for {track_name} by {artist_name}: {str(e)}")
        return None

def process_spotify_data(client_id, client_secret):
    """
    Process Spotify data with API calls and error handling
    """
    # Initialize Spotify client with custom settings
    client_credentials_manager = SpotifyClientCredentials(
        client_id=client_id,
        client_secret=client_secret
    )
    sp = spotipy.Spotify(
        client_credentials_manager=client_credentials_manager,
        requests_timeout=30
    )
    
    # Read streaming history
    with open('StreamingHistory_music_2.json', 'r', encoding='utf-8') as f:
        spotify_data = json.load(f)
    
    # Convert to DataFrame
    df = pd.DataFrame(spotify_data)
    
    # Get unique artist-track combinations
    unique_tracks = df[['artistName', 'trackName']].drop_duplicates()
    print(f"Total unique tracks to process: {len(unique_tracks)}")
    
    # Process tracks in batches
    batch_size = 5  # Process 5 tracks at a time
    processed_tracks = []
    
    for i in range(0, len(unique_tracks), batch_size):
        batch = unique_tracks.iloc[i:i+batch_size]
        batch_num = i//batch_size + 1
        total_batches = len(unique_tracks)//batch_size + 1
        print(f"\nProcessing batch {batch_num}/{total_batches}")
        
        for _, row in batch.iterrows():
            genres = get_track_genres(sp, row['trackName'], row['artistName'])
            if genres:
                processed_tracks.append({
                    'artist': row['artistName'],
                    'track': row['trackName'],
                    'genres': genres
                })
            time.sleep(1)  # Wait 1 second between tracks
        
        time.sleep(2)  # Wait 2 seconds between batches
        
        # Save progress after each batch
        with open('genre_progress.json', 'w', encoding='utf-8') as f:
            json.dump(processed_tracks, f, ensure_ascii=False, indent=2)
    
    print(f"\nSuccessfully processed {len(processed_tracks)} tracks")
    
    # Create genre mapping dictionary
    genre_mapping = {
        (track['artist'], track['track']): track['genres']
        for track in processed_tracks
        if track['genres']
    }
    
    # Add genres to original DataFrame
    df['date'] = pd.to_datetime(df['endTime']).dt.date
    df['genres'] = df.apply(lambda row: genre_mapping.get((row['artistName'], row['trackName']), []), axis=1)
    
    return df# [Cell 1] - Import required libraries
import pandas as pd
import json
import matplotlib.pyplot as plt
import seaborn as sns
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import time
from datetime import datetime
import numpy as np

# [Cell 2] - Load and process Spotify data with genres
def get_track_genres(sp, track_name, artist_name):
    """
    Get genre information for a track using Spotify API with error handling
    """
    try:
        time.sleep(1)  # Add delay between API calls
        # Search for the track
        results = sp.search(q=f"track:{track_name} artist:{artist_name}", type='track', limit=1)
        
        if not results['tracks']['items']:
            print(f"No results found for {track_name} by {artist_name}")
            return None
        
        # Get artist ID
        artist_id = results['tracks']['items'][0]['artists'][0]['id']
        
        time.sleep(1)  # Add delay between API calls
        # Get artist details including genres
        artist = sp.artist(artist_id)
        return artist['genres']
    
    except Exception as e:
        print(f"Error getting genres for {track_name} by {artist_name}: {str(e)}")
        return None

def process_spotify_data(client_id, client_secret):
    """
    Process Spotify data with API calls and error handling
    """
    # Initialize Spotify client with custom settings
    client_credentials_manager = SpotifyClientCredentials(
        client_id=client_id,
        client_secret=client_secret
    )
    sp = spotipy.Spotify(
        client_credentials_manager=client_credentials_manager,
        requests_timeout=30  # Increased timeout for all requests
    )
    
    # Read streaming history
    with open('StreamingHistory_music_2.json', 'r', encoding='utf-8') as f:
        spotify_data = json.load(f)
    
    # Convert to DataFrame
    df = pd.DataFrame(spotify_data)
    
    # Get unique artist-track combinations and apply some filtering
    unique_tracks = df[['artistName', 'trackName']].drop_duplicates()
    print(f"Total unique tracks to process: {len(unique_tracks)}")
    
    # Process tracks in smaller batches with longer delay
    batch_size = 3  # Even smaller batch size
    processed_tracks = []
    
    for i in range(0, len(unique_tracks), batch_size):
        batch = unique_tracks.iloc[i:i+batch_size]
        batch_num = i//batch_size + 1
        total_batches = len(unique_tracks)//batch_size + 1
        print(f"\nProcessing batch {batch_num}/{total_batches}")
        
        for _, row in batch.iterrows():
            print(f"Getting genres for: {row['trackName']} by {row['artistName']}")
            genres = get_track_genres(sp, row['trackName'], row['artistName'])
            if genres:
                processed_tracks.append({
                    'artist': row['artistName'],
                    'track': row['trackName'],
                    'genres': genres
                })
        
        time.sleep(3)  # Even longer delay between batches
    
    print(f"\nSuccessfully processed {len(processed_tracks)} tracks")
    
    # Create genre mapping dictionary
    genre_mapping = {
        (track['artist'], track['track']): track['genres']
        for track in processed_tracks
        if track['genres']  # Only include tracks where we successfully got genres
    }
    
    # Add genres to original DataFrame
    df['date'] = pd.to_datetime(df['endTime']).dt.date
    df['genres'] = df.apply(lambda row: genre_mapping.get((row['artistName'], row['trackName']), []), axis=1)
    
    return df

# [Cell 3] - Process spending data
def get_spending_data():
    """
    Read and process bank transaction data
    """
    bank_df = pd.read_excel('HesapHareketleri_28.11.2024_0124383 (1).xlsx', 
                           skiprows=8,
                           names=['Date', 'Time', 'Amount', 'Balance', 'Description', 'Receipt'])
    
    bank_df = bank_df[bank_df['Date'].str.match(r'\d{2}\.\d{2}\.\d{4}', na=False)]
    bank_df['date'] = pd.to_datetime(bank_df['Date'], format='%d.%m.%Y').dt.date
    bank_df['Amount'] = pd.to_numeric(bank_df['Amount'], errors='coerce')
    
    daily_spending = bank_df.groupby('date')['Amount'].sum().reset_index()
    return daily_spending

# [Cell 4] - Analyze genre-spending relationships
def analyze_genre_spending(spotify_df, spending_df):
    """
    Analyze relationship between genres and spending
    """
    # Explode genres list to get one row per genre
    genre_df = spotify_df.explode('genres')
    genre_df = genre_df.rename(columns={'genres': 'genre'})
    
    # Remove rows where genre is None
    genre_df = genre_df.dropna(subset=['genre'])
    
    # Calculate daily listening time per genre
    genre_daily = genre_df.groupby(['date', 'genre'])['msPlayed'].sum().reset_index()
    genre_daily['minutes_played'] = genre_daily['msPlayed'] / (1000 * 60)
    
    # Merge with spending data
    merged_df = pd.merge(genre_daily, spending_df, on='date', how='inner')
    
    # Calculate statistics for each genre
    genre_stats = []
    min_days = 5  # Minimum number of days to consider
    
    for genre in merged_df['genre'].unique():
        genre_data = merged_df[merged_df['genre'] == genre]
        if len(genre_data) >= min_days:
            correlation = genre_data['minutes_played'].corr(genre_data['Amount'])
            avg_spending = genre_data['Amount'].mean()
            
            genre_stats.append({
                'genre': genre,
                'correlation': correlation,
                'total_minutes': genre_data['minutes_played'].sum(),
                'avg_spending': avg_spending,
                'days_listened': len(genre_data)
            })
    
    return pd.DataFrame(genre_stats)

# [Cell 5] - Create visualizations
def create_visualizations(genre_stats_df):
    """
    Create genre analysis visualizations
    """
    # Sort by absolute correlation
    genre_stats_df['abs_correlation'] = abs(genre_stats_df['correlation'])
    genre_stats_df = genre_stats_df.sort_values('abs_correlation', ascending=False)
    
    # Select top genres by listening time
    top_genres = genre_stats_df.nlargest(10, 'total_minutes')
    
    # Create figure
    plt.style.use('default')
    fig, axes = plt.subplots(2, 1, figsize=(12, 12))
    
    # Plot 1: Correlations
    sns.barplot(data=top_genres,
                x='correlation',
                y='genre',
                ax=axes[0])
    axes[0].set_title('Top 10 Genre-Spending Correlations')
    axes[0].set_xlabel('Correlation Coefficient')
    axes[0].axvline(x=0, color='black', linestyle='-', alpha=0.2)
    
    # Plot 2: Average spending by genre
    sns.barplot(data=top_genres,
                x='avg_spending',
                y='genre',
                ax=axes[1])
    axes[1].set_title('Average Daily Spending by Genre')
    axes[1].set_xlabel('Average Spending (TL)')
    
    plt.tight_layout()
    return fig

# [Cell 6] - Main execution
def main():
    # Spotify API credentials
    CLIENT_ID = '82d3f15f60ee4fd08d64f23a2b2bd8de'
    CLIENT_SECRET = '5b892d88f74a4465af1a66d81c571d15'
    
    try:
        # Get Spotify data with genres
        spotify_df = process_spotify_data(CLIENT_ID, CLIENT_SECRET)
        
        # Get spending data
        spending_df = get_spending_data()
        
        # Analyze relationships
        genre_stats = analyze_genre_spending(spotify_df, spending_df)
        
        # Create and save visualizations
        fig = create_visualizations(genre_stats)
        plt.savefig('genre_spending_analysis.png', dpi=300, bbox_inches='tight')
        plt.close()
        
        # Print results
        print("\nGenre-Spending Analysis Results:")
        print(f"\nTotal genres analyzed: {len(genre_stats)}")
        print("\nTop positive correlations:")
        print(genre_stats.nlargest(5, 'correlation')[['genre', 'correlation', 'avg_spending']].round(2))
        print("\nTop negative correlations:")
        print(genre_stats.nsmallest(5, 'correlation')[['genre', 'correlation', 'avg_spending']].round(2))
        
    except Exception as e:
        print(f"An error occurred: {str(e)}")

if __name__ == "__main__":
    main()
# Out:
# Total unique tracks to process: 1896
#
# Processing batch 1/633
# Getting genres for: Zor by Lvbel C5
# Getting genres for: Beni Her Yerden Engellemiş by cakal
# Getting genres for: Generationwhy by ZHU
#
# Processing batch 2/633
# Getting genres for: Hate It Or Love It by The Game
# Getting genres for: Cuma by cakal
# Getting genres for: Soktuğu Duruma Bak by Murat Dalkılıç
#
# Processing batch 3/633
# Getting genres for: Anlamazdın by Ayla Dikmen
# Getting genres for: Uzun Lafın Kısası by Ozan Doğulu
# Getting genres for: Birtanem - Night Club Mix by Yaşar
#
# Processing batch 4/633
# Getting genres for: Bir İhtimal Biliyorum by Gülşen
# Getting genres for: Marlon Brando by Zeynep Bastık
# Getting genres for: Salty Sip by Hayzei
#
# Processing batch 5/633
# Getting genres for: Vent by NOIT
# Getting genres for: Something About You by Hayden James
# Getting genres for: Sığamıyorum by Bengü
#
# Processing batch 6/633
# Getting genres for: Jest Oldu by Mustafa Sandal
# Getting genres for: Kalbim (Slow Versiyon) by Bengü
# Getting genres for: Ayy / Ben Hala Rüyada by Oğuzhan Koç
#
# Processing batch 7/633
# Getting genres for: Tabi Tabi by Sinan Akçıl
# Getting genres for: Yalan by EDIS
# Getting genres for: Sevdanın Son Vuruşu by Tarkan
#
# Processing batch 8/633
# Getting genres for: An by EDIS
# Getting genres for: Hayırlı Günler by Aydın Kurtoğlu
# Getting genres for: Paşa Paşa by Yasin Keleş
#
# Processing batch 9/633
# Getting genres for: Sakin Ol - Radio Mix by Doğukan Manço
# Getting genres for: Güzelliğine by EDIS
# Getting genres for: Soygun Var by Atiye
#
# Processing batch 10/633
# Getting genres for: Olan Var Olmayan Var by Beyza Durmaz
# Getting genres for: Sigue by Beny Jr
# Getting genres for: Diğer Yarım by ATE
#
# Processing batch 11/633
# Getting genres for: Gülün Rengi by Serdar Ortaç
# Getting genres for: 10 NUMARA by Lvbel C5
# Getting genres for: Dibine Kadar by Duman
#
# Processing batch 12/633
# Getting genres for: Seni Kendime Sakladım by Duman
# Getting genres for: I Kissed A Girl by Katy Perry
# Getting genres for: SUBMARINER by AKDO
#
# Processing batch 13/633
# Getting genres for: Çılgın Dersane by Oğuz Kaplangı
# Getting genres for: YAPAMAM by Lvbel C5
# Getting genres for: Papaoutai by Stromae
#
# Processing batch 14/633
# Getting genres for: CISTAK by Era7capone
# Getting genres for: Amo aller Amos by Amo
# Getting genres for: Hala Madrid ...y nada más by Real Madrid
#
# Processing batch 15/633
# Getting genres for: NKBİ X YAPAMAM - Remix by Lvbel C5
# Getting genres for: olsun by Lvbel C5
# Getting genres for: Mood by Makar
#
# Processing batch 16/633
# Getting genres for: The Boy Is Mine by James Mac
# Getting genres for: Good Life by ZHU
# Getting genres for: Because You Move Me by Tinlicker
#
# Processing batch 17/633
# Getting genres for: I Got U by Duke Dumont
# Getting genres for: Cocaine Model by ZHU
# Getting genres for: Faded by ZHU
#
# Processing batch 18/633
# Getting genres for: Düğün Dernek by Jeff Redd
# Getting genres for: Küvet by Ezhel
# Getting genres for: Hot by INNA
#
# Processing batch 19/633
# Getting genres for: Hold His Own by D-Phunk420
# Getting genres for: MAN DOWN FREESTYLE by Motive
# Getting genres for: Still D.R.E. by Dr. Dre
#
# Processing batch 20/633
# Getting genres for: Diyardan Diyara by cakal
# Getting genres for: Riv Riv Riv by cakal
# Getting genres for: İNATLA by Lvbel C5
#
# Processing batch 21/633
# Getting genres for: İltimas by Gülşen
# Getting genres for: Sonsuz Ol - Remastered by Yalın
# Getting genres for: Superman by Eminem
#
# Processing batch 22/633
# Getting genres for: Inndia by INNA
# Getting genres for: Alors on danse - Radio Edit by Stromae
# Getting genres for: Ocean Drive by Duke Dumont
#
# Processing batch 23/633
# Getting genres for: Dame La Mano by INNA
# Getting genres for: Give It To Me - Full Vocal Mix by Matt Sassari
# Getting genres for: Are You With Me by Lost Frequencies
#
# Processing batch 24/633
# Getting genres for: Chantaje (feat. Maluma) by Shakira
# Getting genres for: Chica Bomb by Dan Balan
# Getting genres for: Loca (feat. Dizzee Rascal) by Shakira
#
# Processing batch 25/633
# Getting genres for: Bulletproof by La Roux
# Getting genres for: I Adore You (feat. Daecolm) by HUGEL
# Getting genres for: Freed from Desire (feat. Indiiana) by Drenchill
#
# Processing batch 26/633
# Getting genres for: Summertime Sadness (Lana Del Rey Vs. Cedric Gervais) - Cedric Gervais Remix by Lana Del Rey
# Getting genres for: Bonbon by Era Istrefi
# Getting genres for: Need Me Baby - Radio Edit by Reea
#
# Processing batch 27/633
# Getting genres for: Take Me Home by Makar
# Getting genres for: Ruleta by INNA
# Getting genres for: You Don't Know Me (feat. RAYE) by Jax Jones
#
# Processing batch 28/633
# Getting genres for: Welcome to St. Tropez - DJ Antoine vs. Mad Mark Radio Edit by DJ Antoine
# Getting genres for: Rude Boy by Rihanna
# Getting genres for: 6 Days by Mahmut Orhan
#
# Processing batch 29/633
# Getting genres for: careless whisper - slowed + reverb by slō
# Getting genres for: Careless Whisper (slowed + reverb) by ghostly echoes
# Getting genres for: Yaz Günü by Hadise
#
# Processing batch 30/633
# Getting genres for: Şıkır Şıkır by Gülben Ergen
# Getting genres for: İsyankar by Mustafa Sandal
# Getting genres for: İşim Olmaz by Tarkan
#
# Processing batch 31/633
# Getting genres for: Kırk Yılda Bir Gibisin by Emrah Karaduman
# Getting genres for: Outside (feat. Ellie Goulding) by Calvin Harris
# Getting genres for: Desire - Play & Win Radio Edit by Morris
#
# Processing batch 32/633
# Getting genres for: Sub pielea mea - Midi Culture Remix by Carla's Dreams
# Getting genres for: Don't Be so Shy - Filatov & Karas Remix by Imany
# Getting genres for: Bad Boys by INNA
#
# Processing batch 33/633
# Getting genres for: Cola Song (feat. J Balvin) by INNA
# Getting genres for: My Love by Route 94
# Getting genres for: Destination Calabria - Radio Edit by Alex Gaudino
#
# Processing batch 34/633
# Getting genres for: Breathe by Parah Dice
# Getting genres for: Move by Adam Port
# Getting genres for: VUR by BLOK3
#
# Processing batch 35/633
# Getting genres for: Feel (feat. Sena Sener) - Radio Edit by Mahmut Orhan
# Getting genres for: Tattoo (Hardstyle Mix) by LORD HADES
# Getting genres for: Ride It by Regard
#
# Processing batch 36/633
# Getting genres for: Je M'appelle by Benzz
# Getting genres for: Koltuklar Full by Woohox
# No results found for Koltuklar Full by Woohox
# Getting genres for: Sing It Back (feat. Naila) by Ash
#
# Processing batch 37/633
# Getting genres for: The Motto by Tiësto
# Getting genres for: Big Shark by Russ Millions
# Getting genres for: Dua by Güneş
#
# Processing batch 38/633
# Getting genres for: Cennet by Ebru Gündeş
# Getting genres for: Don't Stop the Music by Ed Marquis
# Getting genres for: Ders Olsun by Demet Akalın
#
# Processing batch 39/633
# Getting genres for: Ferrari - Remix by James Hype
# Getting genres for: Sevmiş Gibi by Eftalya Yağcı
# Getting genres for: Pırlanta by Demet Akalın
#
# Processing batch 40/633
# Getting genres for: Heartless by Kanye West
# Getting genres for: Alkışlar by Erdem Kınay
# Getting genres for: BAYBAY by BLOK3
#
# Processing batch 41/633
# Getting genres for: GELMEZSEN GELME by Lvbel C5
# Getting genres for: CİRO by BLOK3
# Getting genres for: Felaket by Ezhel
#
# Processing batch 42/633
# Getting genres for: aklına ben gelicem by BLOK3
# Getting genres for: Margiela by Ezhel
# Getting genres for: SENIN UGRUNA by UZI
#
# Processing batch 43/633
# Getting genres for: Patlat by BLOK3
# Getting genres for: Salla Salla by BLOK3
# Getting genres for: Promilim Yüksek by cakal
#
# Processing batch 44/633
# Getting genres for: Keyfi Yolunda Aşkı Sonunda by Yalın
# Getting genres for: A La Carte by Kleo
# Getting genres for: Ölüler Konuşamaz by Farazi
#
# Processing batch 45/633
# Getting genres for: Gangsta Track by Dark Boy
# Getting genres for: Aşk Olsun by cakal
# Getting genres for: Saat 03.00 (By Erhan Bayrak) by Bengü
#
# Processing batch 46/633
# Getting genres for: Deja Vu by INNA
# Getting genres for: Ferrari (Slowed Remix) by Slowed Remix DJ
# Getting genres for: Yüzyılın Aşkı by Sinan Akçıl
#
# Processing batch 47/633
# Getting genres for: Intro (Infected) - Slowed by Linear Phase
# Getting genres for: Mingoflalar by cakal
# Getting genres for: Party With A Jagaban by Midas the Jagaban
#
# Processing batch 48/633
# Getting genres for: Gata Only by FloyyMenor
# Getting genres for: Damlarsın by cakal
# Getting genres for: Bolide Allemand Afro - Remix by DJ Anilson
#
# Processing batch 49/633
# Getting genres for: nE !? by Lvbel C5
# Getting genres for: Loading by Central Cee
# Getting genres for: Mentalité by Baby Gang
#
# Processing batch 50/633
# Getting genres for: Alors Alors by Benzz
# Getting genres for: ILTIMAS X SUBMARINER by AKDO
# Getting genres for: Hayırlı Günler 2.0 by rash
# No results found for Hayırlı Günler 2.0 by rash
#
# Processing batch 51/633
# Getting genres for: Bye Bye by Gülden
# Getting genres for: Moonlight by XXXTENTACION
# Getting genres for: Love by INNA
#
# Processing batch 52/633
# Getting genres for: Diggy Down by INNA
# Getting genres for: YAKALARSAN by cakal
# Getting genres for: GAZ PEDAL by Lvbel C5
#
# Processing batch 53/633
# Getting genres for: MALA (feat. Anuel AA) by 6ix9ine
# Getting genres for: Welcome To Jamrock by Damian Marley
# Getting genres for: Seya by SativaMusic
#
# Processing batch 54/633
# Getting genres for: Un Momento - Play & Win Radio Version by INNA
# Getting genres for: Tell Me by INNA
# Getting genres for: Take Me Home (Know You Better) by INNA
#
# Processing batch 55/633
# Getting genres for: Don't Let the Music Die by INNA
# Getting genres for: Caliente by INNA
# Getting genres for: Club Rocker - Play & Win Radio Version by INNA
#
# Processing batch 56/633
# Getting genres for: Kalbe Zarar by cakal
# Getting genres for: UP by INNA
# Getting genres for: Nirvana by INNA
#
# Processing batch 57/633
# Getting genres for: JET BABA by cakal
# Getting genres for: In Your Eyes by INNA
# Getting genres for: İZLEDİ MAHALLE by Lvbel C5
#
# Processing batch 58/633
# Getting genres for: HAYRAN KALICAN by cakal
# Getting genres for: Dünya Fani by cakal
# Getting genres for: Heaven by INNA
#
# Processing batch 59/633
# Getting genres for: DACIA by Lvbel C5
# Getting genres for: Secrets by Tiësto
# Getting genres for: Vois sur ton chemin - Techno Mix by BENNETT
#
# Processing batch 60/633
# Getting genres for: Maneater by JKRS
# Getting genres for: GÖNDER GELSİN by Lvbel C5
# Getting genres for: OF OF OF by ElMusto
#
# Processing batch 61/633
# Getting genres for: Boyz In Paris (with VINAI) by Marnik
# Getting genres for: Push Up - Main Edit by Creeds
# Getting genres for: Thank You (Not So Bad) by Dimitri Vegas & Like Mike
#
# Processing batch 62/633
# Getting genres for: Rockstar by Ilkay Sencan
# Getting genres for: Me Provocas by Dynoro
# Getting genres for: Chanel by Frank Ocean
#
# Processing batch 63/633
# Getting genres for: Danza Kuduro by Don Omar
# Getting genres for: Only Girl (In The World) by Rihanna
# Getting genres for: Moonlight by Gaullin
#
# Processing batch 64/633
# Getting genres for: Kids (feat. MKLA) by KSHMR
# Getting genres for: Right Now (Na Na Na) by Akon
# Getting genres for: One Night in Ibiza by Mike Candys
#
# Processing batch 65/633
# Getting genres for: International Love (feat. Chris Brown) by Pitbull
# Getting genres for: Delilah by MIKOLAS
# Getting genres for: Get Busy by Sean Paul
#
# Processing batch 66/633
# Getting genres for: Mr. Saxobeat - Radio Edit by Alexandra Stan
# Getting genres for: Hotel Room Service by Pitbull
# Getting genres for: TEMPERATURA by Skolim
#
# Processing batch 67/633
# Getting genres for: Turn Me On - Extended by David Guetta
# Getting genres for: Disturbia by Rihanna
# Getting genres for: Sexy Bitch (feat. Akon) by David Guetta
#
# Processing batch 68/633
# Getting genres for: Don't Stop The Music by Rihanna
# Getting genres for: Ma Chérie - DJ Antoine & Mad Mark 2K12 Radio Edit by DJ Antoine
# Getting genres for: Obsessed - Sped Up by Six Dior
#
# Processing batch 69/633
# Getting genres for: Oh You Don't Mean Nothing at All to Me by Dj Rehan
# Getting genres for: Follow The Leader by Wisin & Yandel
# Getting genres for: Ostatni raz zatańczysz ze mną by Tribbs
#
# Processing batch 70/633
# Getting genres for: Temperature by Sean Paul
# Getting genres for: Mademoiselle by Blacha 2115
# Getting genres for: Wet - Remix by Snoop Dogg
#
# Processing batch 71/633
# Getting genres for: Rain Over Me (feat. Marc Anthony) by Pitbull
# Getting genres for: More - RedOne Jimmy Joker Remix by USHER
# Getting genres for: Czarne bluzy by PlanBe
#
# Processing batch 72/633
# Getting genres for: In Da Club by 50 Cent
# Getting genres for: Tommy gun by Kacper HTA
# Getting genres for: Get Up (Rattle) [feat. Far East Movement] - Vocal Edit by Bingo Players
#
# Processing batch 73/633
# Getting genres for: She Makes Me Go (feat. Sean Paul) - Radio Edit by Arash
# Getting genres for: Umbrella by Rihanna
# Getting genres for: Hey Baby (Drop It to the Floor) (feat. T-Pain) by Pitbull
#
# Processing batch 74/633
# Getting genres for: False Alarm by The Weeknd
# Getting genres for: Me Gustas Tu by Manu Chao
# Getting genres for: Susanna (Susanna) - Remastered by Adriano Celentano
#
# Processing batch 75/633
# Getting genres for: Ma Che Freddo Fa by Nada
# Getting genres for: L'Italiano by Ciao Italia !
# Getting genres for: Maledetta primavera by Loretta Goggi
#
# Processing batch 76/633
# Getting genres for: Yamore X Move by AFRO
# Getting genres for: IMPARATOR by Sefo
# Getting genres for: Casanova - Sefo Remix by Soolking
#
# Processing batch 77/633
# Getting genres for: In the Morning by ZHU
# Getting genres for: Freed From Desire - prod. Molella, Phil Jay by Gala
# Getting genres for: I Was Never There by The Weeknd
#
# Processing batch 78/633
# Getting genres for: Go Down Deh (feat. Sean Paul & Shaggy) by Spice
# Getting genres for: Sugar (feat. Francesco Yates) by Robin Schulz
# Getting genres for: Him & I (with Halsey) by G-Eazy
#
# Processing batch 79/633
# Getting genres for: The Hills by The Weeknd
# Getting genres for: Friday (feat. Mufasa & Hypeman) - Dopamine Re-Edit by Riton
# Getting genres for: New Rules by Dua Lipa
#
# Processing batch 80/633
# Getting genres for: Me, Myself & I by G-Eazy
# Getting genres for: Pon De Replay by Ed Marquis
# Getting genres for: Crazy In Love (feat. Jay-Z) by Beyoncé
#
# Processing batch 81/633
# Getting genres for: How Deep Is Your Love by Calvin Harris
# Getting genres for: Often by The Weeknd
# Getting genres for: I'm Good (Blue) by David Guetta
#
# Processing batch 82/633
# Getting genres for: Call Out My Name - Live by The Weeknd
# Getting genres for: My Ordinary Life by The Living Tombstone
# Getting genres for: Prayer in C - Robin Schulz Radio Edit by Lilly Wood and The Prick
#
# Processing batch 83/633
# Getting genres for: ralli by Lvbel C5
# Getting genres for: Sun Is Up by INNA
# Getting genres for: Endless by INNA
#
# Processing batch 84/633
# Getting genres for: behzat ç by Lvbel C5
# Getting genres for: İmdat by cakal
# Getting genres for: Wavin' Flag - Coca-Cola® Celebration Mix by K'NAAN
#
# Processing batch 85/633
# Getting genres for: Yerli Plaka by cakal
# Getting genres for: Sweater Weather by Gaullin
# Getting genres for: Lemonade (feat. NAV) by Internet Money
#
# Processing batch 86/633
# Getting genres for: MY EYES by Travis Scott
# Getting genres for: Heartbeat - Speed by Ren
# Getting genres for: Believe Me by Navos
#
# Processing batch 87/633
# Getting genres for: Moth To A Flame (with The Weeknd) by Swedish House Mafia
# Getting genres for: Yeşil Su by Serdar Ortaç
# Getting genres for: Aşk Diye by Yalın
#
# Processing batch 88/633
# Getting genres for: Ya Habibi by Atiye
# Getting genres for: Gamzelim by Serdar Ortaç
# Getting genres for: Helal Ettim by Erdem Kınay
#
# Processing batch 89/633
# Getting genres for: Azzurro - Remastered by Adriano Celentano
# Getting genres for: Mambo Italiano by Dean Martin
# Getting genres for: This Is What You Came For by Calvin Harris
#
# Processing batch 90/633
# Getting genres for: Love in Portofino by Fred Buscaglione
# Getting genres for: Parole parole - 2001 Remastered Version by Mina
# Getting genres for: Go Gyal - Extended Mix by Ahzee
#
# Processing batch 91/633
# Getting genres for: One Kiss (with Dua Lipa) by Calvin Harris
# Getting genres for: I Will Survive - Original 7" Version by Gloria Gaynor
# Getting genres for: Gimme! Gimme! Gimme! (A Man After Midnight) by ABBA
#
# Processing batch 92/633
# Getting genres for: I Took A Pill In Ibiza - Seeb Remix by Mike Posner
# Getting genres for: Rodri's On Fire by Paul Hand
# Getting genres for: Pretty Please by Dua Lipa
#
# Processing batch 93/633
# Getting genres for: Gangsta Boo (with Lil Tjay) by Ice Spice
# Getting genres for: ŞU AN by ALIZADE
# Getting genres for: Attention (Nightcore) by Syrex
#
# Processing batch 94/633
# Getting genres for: Prada (feat. D-Block Europe) - Acoustic Version by cassö
# Getting genres for: Save Me (feat. Eneli) by Mahmut Orhan
# Getting genres for: Right Here by Chase Atlantic
#
# Processing batch 95/633
# Getting genres for: Con Te Partirò by Andrea Bocelli
# Getting genres for: Tu vuo' fa l'americano by Renato Carosone
# Getting genres for: Mambo italiano by Carla Boni
#
# Processing batch 96/633
# Getting genres for: Tu Vuo Fa L' Americano by Sophia Loren
# Getting genres for: Felicità by Al Bano And Romina Power
# Getting genres for: Moth to a Flame x After Hours - Sp3d Up by Velvet Horizon
#
# Processing batch 97/633
# Getting genres for: Amado Mio by Orietta Berti
# Getting genres for: Bir Gün Olsun Terketmedik by Tribün Besteleri
# Getting genres for: Harder, Better, Faster, Stronger by Daft Punk
#
# Processing batch 98/633
# Getting genres for: Lost My Mind by FiloChill
# Getting genres for: SABRETMEM by Karayel226
# Getting genres for: Disconnected by James Hype
#
# Processing batch 99/633
# Getting genres for: Prada by cassö
# Getting genres for: Gülümse Kaderine by Tarkan
# Getting genres for: Toskoya Fifa'da Koydum by batuf1x
# No results found for Toskoya Fifa'da Koydum by batuf1x
#
# Processing batch 100/633
# Getting genres for: all eyez on me - lofi by lonelyboy
# Getting genres for: Bir Fırt Çek by Gülşen
# Getting genres for: Korkma Kalbim (Klip Versiyon) by Bengü
#
# Processing batch 101/633
# Getting genres for: Şinanay by Sezen Aksu
# Getting genres for: Yansıma by Derya Uluğ
# Getting genres for: Poşet by Serdar Ortaç
#
# Processing batch 102/633
# Getting genres for: Gülümse Kaderine by Kibariye
# Getting genres for: Gidemem by Kibariye
# Getting genres for: Mohikan Marşı by GFB
#
# Processing batch 103/633
# Getting genres for: Kardan Aydınlık by Teymullah
# Getting genres for: Aşk Gitti Bizden by Ozan Çolakoğlu
# Getting genres for: Adımı Kalbine Yaz by Tarkan
#
# Processing batch 104/633
# Getting genres for: Aldırma Deli Gönlüm by Sertab Erener
# Getting genres for: Benden Sonra by Hande Yener
# Getting genres for: Günah Sevap by Aynur Aydın
#
# Processing batch 105/633
# Getting genres for: Olacak Olacak by Demet Akalın
# Getting genres for: Gölge by Demet Akalın
# Getting genres for: Beni Sev by Hande Yener
#
# Processing batch 106/633
# Getting genres for: Boynun Borcu by Erdem Kınay
# Getting genres for: Ben Adam Olmam by Serdar Ortaç
# Getting genres for: Asrın Hatası by Serdar Ortaç
#
# Processing batch 107/633
# Getting genres for: Too Sweet by Hozier
# Getting genres for: Yasak Aşk by Hande Yener
# Getting genres for: Hovarda by Emel Müftüoğlu
#
# Processing batch 108/633
# Getting genres for: Duman by Erdem Kınay
# Getting genres for: Süpriz by Gülben Ergen
# Getting genres for: FE!N (feat. Playboi Carti) by Travis Scott
#
# Processing batch 109/633
# Getting genres for: International by Russ Millions
# Getting genres for: Sınana Sınana by Duman
# Getting genres for: Working For It by ZHU
#
# Processing batch 110/633
# Getting genres for: Jerk It Out by Caesars
# Getting genres for: BÖLÜM SONU by Güneş
# Getting genres for: Hayatı Yaşa by Duman
#
# Processing batch 111/633
# Getting genres for: Hayatı Yaşa - Live At Boğaziçi Üniversitesi Spor Festivali, İstanbul / 2003 by Duman
# Getting genres for: Dip by Onur Can Özcan
# Getting genres for: Uzaktan by Göksel
#
# Processing batch 112/633
# Getting genres for: DOYAMADIM by AKDO
# Getting genres for: Kalpten Dudağa by Ozan Çolakoğlu
# Getting genres for: Sopa - Dance Remix by Hande Yener
#
# Processing batch 113/633
# Getting genres for: Kafile by Yüksek Sadakat
# Getting genres for: Helal Ettim - DJ Eyüp Remix by Merve Özbey
# Getting genres for: MAGAZIN by UZI
#
# Processing batch 114/633
# Getting genres for: Me Gustas Tu - Slowed and Reverb Version by Manu Chao
# Getting genres for: ME GUSTA by Paco
# Getting genres for: Yakar Geçerim by Ajda Pekkan
#
# Processing batch 115/633
# Getting genres for: Bir Bakmışsın by Yalın
# Getting genres for: Havalı Yarim by Serdar Ortaç
# Getting genres for: Hani Bana by Hande Yener
#
# Processing batch 116/633
# Getting genres for: Karardı Bulutlar by Wegh
# Getting genres for: I WANNA DANCE by Batuflex
# Getting genres for: Eski Bıçaklar Yeni Kesikler by Sagopa Kajmer
#
# Processing batch 117/633
# Getting genres for: TEMPO by Lvbel C5
# Getting genres for: Düşmez Kalkmaz by Canbay & Wolker
# Getting genres for: Sezen Aksu by Lvbel C5
#
# Processing batch 118/633
# Getting genres for: Kennedy'i Ben Vurdum by Wegh
# Getting genres for: Shoote Shoote by Ati242
# Getting genres for: Sadeness by Enigma
#
# Processing batch 119/633
# Getting genres for: Lost in the Fire (feat. The Weeknd) by Gesaffelstein
# Getting genres for: We Are One (Ole Ola) [The Official 2014 FIFA World Cup Song] (feat. Jennifer Lopez & Claudia Leitte) by Pitbull
# Getting genres for: Coco Jamboo - Calippo Remix Edit by Angelika Vee
#
# Processing batch 120/633
# Getting genres for: Stereo Love - Twelve Remix by Edward Maya
# Getting genres for: Yalla by INNA
# Getting genres for: Pepas by Farruko
#
# Processing batch 121/633
# Getting genres for: Me, Myself & I - Marc Stout & Scott Svejda Remix by G-Eazy
# Getting genres for: Smooth Operator - Single Version by Sade
# Getting genres for: Waves by T.H. Express
#
# Processing batch 122/633
# Getting genres for: More Than Friends by INNA
# Getting genres for: Play Hard (feat. Ne-Yo & Akon) - New Edit by David Guetta
# Getting genres for: In Your Eyes by The Weeknd
#
# Processing batch 123/633
# Getting genres for: Loca People by Sak Noel
# Getting genres for: Can't Remember to Forget You (feat. Rihanna) by Shakira
# Getting genres for: Promiscuous X Motive by void angel
#
# Processing batch 124/633
# Getting genres for: Prayer in C - Robin Schulz Remix by Lilly Wood and The Prick
# Getting genres for: Wake Me Up by Avicii
# Getting genres for: Fireball (feat. John Ryan) by Pitbull
#
# Processing batch 125/633
# Getting genres for: Pray For Me by The Weeknd
# Getting genres for: Around the World by Daft Punk
# Getting genres for: Calabria (feat. Lunis & Lujavo) by Dance Fruits Music
#
# Processing batch 126/633
# Getting genres for: Runaway (U & I) - Svidden & Jarly Remix; Paper Towns Soundtrack Version by Galantis
# Getting genres for: The Morning After by NTO
# Getting genres for: Baianá by Bakermat
#
# Processing batch 127/633
# Getting genres for: Secrets by The Weeknd
# Getting genres for: Dark Red by Steve Lacy
# Getting genres for: Lush Life by Zara Larsson
#
# Processing batch 128/633
# Getting genres for: Let Me Love You by DJ Snake
# Getting genres for: Dancin (feat. Luvli) - Krono Remix by Aaron Smith
# Getting genres for: Home by Mahalo
#
# Processing batch 129/633
# Getting genres for: Parado no Bailão by MC L da Vinte
# Getting genres for: Outside - Slowed + Reverb by skyemane
# Getting genres for: You Will See by Quarterhead
#
# Processing batch 130/633
# Getting genres for: BELLYDANCING by INJI
# Getting genres for: Sarà perché ti amo by Ricchi E Poveri
# Getting genres for: Lost on You by LP
#
# Processing batch 131/633
# Getting genres for: I got summer on my mind by Lewis Hanton
# Getting genres for: В экстазе by Misha Xramovi
# Getting genres for: Özlesen Beni by cakal
#
# Processing batch 132/633
# Getting genres for: Me Gustas Tu - Sped Up Version by Manu Chao
# Getting genres for: Cool Kadın - Mahmut Orhan Remix by Ajda Pekkan
# Getting genres for: Sallandım by Morphia
#
# Processing batch 133/633
# Getting genres for: ARABA by M Lisa
# Getting genres for: L'italiano by Toto Cutugno
# Getting genres for: Nabız by Hidra
#
# Processing batch 134/633
# Getting genres for: Esenyurt Trap Pafküf by Tuhan
# Getting genres for: Happy Nation - Radio Edit by Ace of Base
# Getting genres for: Sopa - Clup Remix by Hande Yener
#
# Processing batch 135/633
# Getting genres for: Swing - Mahmut Orhan Remix by Sofi Tukker
# Getting genres for: Değişmene Rağmen by Ati242
# Getting genres for: Suçlarımdan Biri by Güneş
#
# Processing batch 136/633
# Getting genres for: No Coke (7'' Mix) by Dr. Alban
# Getting genres for: Kayboluyorum (educatedear Remix) by Sedef Sebüktekin
# Getting genres for: Kayboluyorum (Süt) by Sedef Sebüktekin
#
# Processing batch 137/633
# Getting genres for: Bir Mahsun Mor Menekşe by Genç Fenerbahçeliler
# Getting genres for: Revenge by XXXTENTACION
# Getting genres for: Falling Down - Bonus Track by Lil Peep
#
# Processing batch 138/633
# Getting genres for: Fuck Love by XXXTENTACION
# Getting genres for: I Don't Wanna Do This Anymore by XXXTENTACION
# Getting genres for: Hope by XXXTENTACION
#
# Processing batch 139/633
# Getting genres for: Again (feat. XXXTENTACION) by Noah Cyrus
# Getting genres for: Everybody Dies In Their Nightmares by XXXTENTACION
# Getting genres for: Collar of Truth by Fiuge
# No results found for Collar of Truth by Fiuge
#
# Processing batch 140/633
# Getting genres for: Collar of Truth (Speed Up) by Fiuge
# No results found for Collar of Truth (Speed Up) by Fiuge
# Getting genres for: Collar of Truth by VIOLENT VIRA
# Getting genres for: Pressure by Rushy
#
# Processing batch 141/633
# Getting genres for: People You Know - sped up to perfection by TommyMuzzic
# Getting genres for: Bana Aşktan Bahsetme Sen Aşktan Ne Anlarsın by Besteler
# Getting genres for: Sevdiğim Allah Belanı Versin by Tribün Besteleri
#
# Processing batch 142/633
# Getting genres for: Artık Ben İçmiyorum by Tribün Besteleri
# Getting genres for: Sen Istersin by Sedef Sebüktekin
# Getting genres for: Bul Beni by Sedef Sebüktekin
#
# Processing batch 143/633
# Getting genres for: Benimle Gel by Reckol
# Getting genres for: Aşk Her Şeyi Affeder Mi by Şam
# Getting genres for: Bambaşka Biri by Ajda Pekkan
#
# Processing batch 144/633
# Getting genres for: No Role Modelz by J. Cole
# Getting genres for: Ananın A..ı Galatasaray by Genç Fenerbahçeliler
# Getting genres for: Timeless (with Playboi Carti) by The Weeknd
#
# Processing batch 145/633
# Getting genres for: Son Arzum by Nilüfer
# Getting genres for: Formidable by Stromae
# Getting genres for: Sözler Şerefsiz Oldu by Norm Ender
#
# Processing batch 146/633
# Getting genres for: NKBİ by Güneş
# Getting genres for: UZİ - Serbest Stil 3 by SHANZY
# No results found for UZİ - Serbest Stil 3 by SHANZY
# Getting genres for: Aşkın Yalanmış by Göksel
#
# Processing batch 147/633
# Getting genres for: Dynasty by MIIA
# Getting genres for: Freaks by Surf Curse
# Getting genres for: Freaks but Slowed Muffled Echo by Bondex
#
# Processing batch 148/633
# Getting genres for: Freaks - Slowed + Reverb by Khlaws
# Getting genres for: Holigan by Athena
# Getting genres for: Kanunlar Gibi by Derya Uluğ
#
# Processing batch 149/633
# Getting genres for: Salla by Atiye
# Getting genres for: Menekşe by Tepki
# Getting genres for: Yemin Olsun by Ufo361
#
# Processing batch 150/633
# Getting genres for: Allah'ından Bul by Ezhel
# Getting genres for: Kapat Işıklarını by Ufo361
# Getting genres for: Düş Yakamdan by UZI
#
# Processing batch 151/633
# Getting genres for: Bertaraf by Canbay & Wolker
# Getting genres for: Dobro Vecer by Farazi
# Getting genres for: Intro (Infected) by Sickick
#
# Processing batch 152/633
# Getting genres for: DOBRYY VECHER BRAZIL by Emin Nilsen
# Getting genres for: Biladerim İçin by Ben Fero
# Getting genres for: Bonita by Sefo
#
# Processing batch 153/633
# Getting genres for: Dalga by Batuflex
# Getting genres for: Takip by Motive
# Getting genres for: Can't Tell Me Nothing by Kanye West
#
# Processing batch 154/633
# Getting genres for: Omuzumda by NOAH
# Getting genres for: Bones by Imagine Dragons
# Getting genres for: Situationship 2 by SamRecks
#
# Processing batch 155/633
# Getting genres for: Derman by Ezhel
# Getting genres for: Ramenez la coupe à la maison by Vegedream
# Getting genres for: Reminder by The Weeknd
#
# Processing batch 156/633
# Getting genres for: Die For You - Remix by The Weeknd
# Getting genres for: Aşkın Olayım by Simge
# Getting genres for: Love Tonight (David Guetta Remix Edit) by Shouse
#
# Processing batch 157/633
# Getting genres for: 24/7 by ALIZADE
# Getting genres for: Royalty - slowed to perfection by TommyMuzzic
# Getting genres for: Ayrılmam by Serdar Ortaç
#
# Processing batch 158/633
# Getting genres for: HOŞÇAKAL KADAR by Büyük Ev Ablukada
# Getting genres for: Sarılsak Geçer Gibiydi by Sehabe
# Getting genres for: ZOR by UZI
#
# Processing batch 159/633
# Getting genres for: Küle Dönmüşsün by Semicenk
# Getting genres for: Thé à la menthe by La Caution
# Getting genres for: Hobby Hobby by MERO
#
# Processing batch 160/633
# Getting genres for: Bazen (feat. Emel) by Ezhel
# Getting genres for: Wicked Game by Chris Isaak
# Getting genres for: This One's for You (feat. Zara Larsson) (Official Song UEFA EURO 2016) by David Guetta
#
# Processing batch 161/633
# Getting genres for: HER YER FAVELA by Critical
# Getting genres for: Females Lingo - Focus Version by Bsav GP
# Getting genres for: MON LOVE OHO by Liamsi
#
# Processing batch 162/633
# Getting genres for: Rush by Troye Sivan
# Getting genres for: Suave (Kiss Me) (feat. Mohombi & Pitbull) by Nayer
# Getting genres for: (When You Gonna) Give It Up to Me (feat. Keyshia Cole) - Radio Version by Sean Paul
#
# Processing batch 163/633
# Getting genres for: Never Never (feat. Indiiana) - Giorgio Gee Remix by Drenchill
# Getting genres for: Bolide allemand by SDM
# Getting genres for: The Mystic by Adam Jensen
#
# Processing batch 164/633
# Getting genres for: Üzülmedin mi? by Simge
# Getting genres for: Let Me Go by AniLifts
# No results found for Let Me Go by AniLifts
# Getting genres for: You Are by NVOY
#
# Processing batch 165/633
# Getting genres for: Fire - Official UEFA EURO 2024 Song by MEDUZA
# Getting genres for: Obsessed With You by Central Cee
# Getting genres for: Turks & Caicos (feat. 21 Savage) by Rod Wave
#
# Processing batch 166/633
# Getting genres for: Party Monster by The Weeknd
# Getting genres for: Addicted to You by Shakira
# Getting genres for: Bad Boys by Inner Circle
#
# Processing batch 167/633
# Getting genres for: Bad Boys (Theme from Cops) by Inner Circle
# Getting genres for: Giorgio by Moroder by Daft Punk
# Getting genres for: Hiç Işık Yok by No.1
#
# Processing batch 168/633
# Getting genres for: Heveslenmem by Lil Zey
# Getting genres for: Eskisi Gibi by Lil Zey
# Getting genres for: 80 Kere by Lil Zey
#
# Processing batch 169/633
# Getting genres for: Gözyaşı Rapsodi 3 by Khontkar
# Getting genres for: Peygamber Sabrı by Lil Zey
# Getting genres for: 1 gr eksik by Lil Zey
#
# Processing batch 170/633
# Getting genres for: Ride by Twenty One Pilots
# Getting genres for: Makina by UZI
# Getting genres for: Haberi Var Mı by Hande Yener
#
# Processing batch 171/633
# Getting genres for: Ride With Me (feat. Kid Ink) - Brennan Heart Remix by Tungevaag
# Getting genres for: Deva Bize Sevişler by Yalın
# Getting genres for: Traag by Bizzey
#
# Processing batch 172/633
# Getting genres for: Yolumuz Yol Değil by Lil Zey
# Getting genres for: Zor by Lil Zey
# Getting genres for: Olamam İflah by Lil Zey
#
# Processing batch 173/633
# Getting genres for: madem öyle...(rastlaşcaz!) by Lil Zey
# Getting genres for: Diyardan Diyara - Afro House Remix by cakal
# Getting genres for: Paranoya by UZI
#
# Processing batch 174/633
# Getting genres for: Favela by UZI
# Getting genres for: Come Over (feat. Popcaan) by Jorja Smith
# Getting genres for: Come Over (Remix) by Jorja Smith
#
# Processing batch 175/633
# Getting genres for: Neyim Var Ki (feat. Sagopa K) by Ceza
# Getting genres for: ALORS BRAZIL by NONTHENSE
# Getting genres for: Roses - Imanbek Remix by SAINt JHN
#
# Processing batch 176/633
# Getting genres for: pVg by Motive
# Getting genres for: Yasemen by Afra
# Getting genres for: TERRITORY by The Blaze
#
# Processing batch 177/633
# Getting genres for: Beni Hatırla by Nazan Öncel
# Getting genres for: Bir Derdim Var by mor ve ötesi
# Getting genres for: Ayrı Gitme Spd by krmd
#
# Processing batch 178/633
# Getting genres for: Ayrı Gitme 2 by Sydros
# Getting genres for: Ayrı Gitme by Aleyna Tilki
# Getting genres for: Ayrı Gitme by Serdar Ortaç
#
# Processing batch 179/633
# Getting genres for: Solo (feat. Demi Lovato) by Clean Bandit
# Getting genres for: I'll Do It - Slowed by deprezz
# Getting genres for: Bu Gece - Remix by Ozan Çolakoğlu
#
# Processing batch 180/633
# Getting genres for: Yamore X Move by Tazzy
# Getting genres for: Beni Hatırla by Sıla
# Getting genres for: Beni Hatırla by Ceylan Ertem
#
# Processing batch 181/633
# Getting genres for: Matrix by Lil Zey
# Getting genres for: Ötede Dur by KÖK$VL
# Getting genres for: Meditasyon by Lil Zey
#
# Processing batch 182/633
# Getting genres for: OnlyFans by Lil Zey
# Getting genres for: Piç Ettim by Lil Zey
# Getting genres for: DEFOL by Lil Zey
#
# Processing batch 183/633
# Getting genres for: ÇEK (feat. Strick) by Lil Zey
# Getting genres for: Marina by Lil Zey
# Getting genres for: ELMAS by Luciano
#
# Processing batch 184/633
# Getting genres for: Ruhum by Young Bego
# Getting genres for: NAYLON by Lil Zey
# Getting genres for: Çevir Tavukları by Lil Zey
#
# Processing batch 185/633
# Getting genres for: GEÇMİŞİ SİL by Kozmos
# Getting genres for: Vuslat by Lil Zey
# Getting genres for: Ateşi Yak by ilkekw
# No results found for Ateşi Yak by ilkekw
#
# Processing batch 186/633
# Getting genres for: Stronger by Kanye West
# Getting genres for: La Tortura (feat. Alejandro Sanz) by Shakira
# Getting genres for: Where Them Girls At (feat. Nicki Minaj & Flo Rida) by David Guetta
#
# Processing batch 187/633
# Getting genres for: Levels - Radio Edit by Avicii
# Getting genres for: On My Own by Darci
# Getting genres for: favorite by Isabel LaRosa
#
# Processing batch 188/633
# Getting genres for: What You Know Bout Love by Pop Smoke
# Getting genres for: Swim by Chase Atlantic
# Getting genres for: Still Don't Know My Name by Labrinth
#
# Processing batch 189/633
# Getting genres for: Why'd You Only Call Me When You're High? by Arctic Monkeys
# Getting genres for: Animals by Maroon 5
# Getting genres for: True Love by Kanye West
#
# Processing batch 190/633
# Getting genres for: Heartburn by Wafia
# Getting genres for: Fantasy by Bazzi
# Getting genres for: Starboy by The Weeknd
#
# Processing batch 191/633
# Getting genres for: Friends by Chase Atlantic
# Getting genres for: older by Isabel LaRosa
# Getting genres for: Unforgettable by French Montana
#
# Processing batch 192/633
# Getting genres for: Popular (with Playboi Carti & Madonna) - From The Idol Vol. 1 (Music from the HBO Original Series) by The Weeknd
# Getting genres for: After Hours by The Weeknd
# Getting genres for: One Of The Girls (with JENNIE, Lily Rose Depp) by The Weeknd
#
# Processing batch 193/633
# Getting genres for: Embrace It by Ndotz
# Getting genres for: Bandoleros by Don Omar
# Getting genres for: Dark Life (Instrumental) by Savai
#
# Processing batch 194/633
# Getting genres for: Kim Bilir by M Lisa
# Getting genres for: Toca Toca by Fly Project
# Getting genres for: 1, 2, 3 (feat. Jason Derulo & De La Ghetto) by Sofía Reyes
#
# Processing batch 195/633
# Getting genres for: Harder by Helin
# Getting genres for: Patadas de Ahogado / LATÍN MAFIA, HUMBE - Rework by HUGEL
# Getting genres for: PELIGROSA by FloyyMenor
#
# Processing batch 196/633
# Getting genres for: APAGA EL CEL by FloyyMenor
# Getting genres for: Rumba de Barcelona - Live by Manu Chao
# Getting genres for: Morenita by HUGEL
#
# Processing batch 197/633
# Getting genres for: Alibi (with Pabllo Vittar & Yseult) by Sevdaliza
# Getting genres for: Say My Name by David Guetta
# Getting genres for: Hey Sexy Lady by Shaggy
#
# Processing batch 198/633
# Getting genres for: Hips Don't Lie (feat. Wyclef Jean) by Shakira
# Getting genres for: Loco Contigo (feat. J. Balvin & Tyga) by DJ Snake
# Getting genres for: Mi Gente by J Balvin
#
# Processing batch 199/633
# Getting genres for: Me Gusta by DTF
# Getting genres for: LA FALDA by Myke Towers
# Getting genres for: Best Gyal by Blaiz Fayah
#
# Processing batch 200/633
# Getting genres for: Djadja by Aya Nakamura
# Getting genres for: Celoso by Lele Pons
# Getting genres for: Gata Only (Remix) by FloyyMenor
#
# Processing batch 201/633
# Getting genres for: Santa by Rvssian
# Getting genres for: City Boys by Burna Boy
# Getting genres for: Gasolina by Daddy Yankee
#
# Processing batch 202/633
# Getting genres for: Last Last by Burna Boy
# Getting genres for: El Cielo by Sky Rompiendo
# Getting genres for: Mi Luz (ft. Rels B) by Rvfv
#
# Processing batch 203/633
# Getting genres for: Copines by Aya Nakamura
# Getting genres for: In Da Getto by J Balvin
# Getting genres for: Kırık Kalpler by Saipa
# No results found for Kırık Kalpler by Saipa
#
# Processing batch 204/633
# Getting genres for: Yok Yok by Feride Hilal Akın
# Getting genres for: Riptide by Vance Joy
# Getting genres for: Love Me Again by John Newman
#
# Processing batch 205/633
# Getting genres for: Get Lucky (Radio Edit) [feat. Pharrell Williams and Nile Rodgers] by Daft Punk
# Getting genres for: Stereo Hearts (feat. Adam Levine) by Gym Class Heroes
# Getting genres for: Georgia by Vance Joy
#
# Processing batch 206/633
# Getting genres for: Ophelia by The Lumineers
# Getting genres for: Somebody That I Used To Know by Gotye
# Getting genres for: Little Talks by Of Monsters and Men
#
# Processing batch 207/633
# Getting genres for: Good Grief by Bastille
# Getting genres for: Safe and Sound by Capital Cities
# Getting genres for: Pompeii by Bastille
#
# Processing batch 208/633
# Getting genres for: Pumped Up Kicks by Foster The People
# Getting genres for: Rolling in the Deep by Adele
# Getting genres for: Idea 10 by Gibran Alcocer
#
# Processing batch 209/633
# Getting genres for: This Is The Life by Amy Macdonald
# Getting genres for: Daddy Issues by The Neighbourhood
# Getting genres for: I Follow Rivers - The Magician Remix by Lykke Li
#
# Processing batch 210/633
# Getting genres for: Take Me To Church by Hozier
# Getting genres for: Sex, Drugs, Etc. by Beach Weather
# Getting genres for: Sweater Weather by The Neighbourhood
#
# Processing batch 211/633
# Getting genres for: We Don't Talk Anymore (feat. Selena Gomez) by Charlie Puth
# Getting genres for: Nevermind by Dennis Lloyd
# Getting genres for: Do I Wanna Know? by Arctic Monkeys
#
# Processing batch 212/633
# Getting genres for: WASTE by KXLLSWXTCH
# Getting genres for: Strangers by Kenya Grace
# Getting genres for: Si Ai by Tayna
#
# Processing batch 213/633
# Getting genres for: Shut up My Moms Calling by Hotel Ugly
# Getting genres for: Idea 22 by Gibran Alcocer
# Getting genres for: The Color Violet by Tory Lanez
#
# Processing batch 214/633
# Getting genres for: Reflections by The Neighbourhood
# Getting genres for: remember your body by Mckyyy
# Getting genres for: Roi - Instrumental Slowed by Mckyyy
#
# Processing batch 215/633
# Getting genres for: Fall Back by Lithe
# Getting genres for: Walk by Kwabs
# Getting genres for: Star Shopping by Lil Peep
#
# Processing batch 216/633
# Getting genres for: KEHLANI by Jordan Adetunji
# Getting genres for: Forever by ilyTOMMY
# Getting genres for: cross my heart by Artemas
#
# Processing batch 217/633
# Getting genres for: Somebody's Watching Me by Rockwell
# Getting genres for: Sleepless by AVAION
# Getting genres for: Summertime In Paris by Jaden
#
# Processing batch 218/633
# Getting genres for: Wait a Minute! by WILLOW
# Getting genres for: Hey, Soul Sister by Train
# Getting genres for: Welcome Home, Son by Radical Face
#
# Processing batch 219/633
# Getting genres for: Viva La Vida by Coldplay
# Getting genres for: Something Just Like This by The Chainsmokers
# Getting genres for: Yellow by Coldplay
#
# Processing batch 220/633
# Getting genres for: Cupid's Chokehold / Breakfast in America by Gym Class Heroes
# Getting genres for: Mind Over Matter (Reprise) by Young the Giant
# Getting genres for: Clocks by Coldplay
#
# Processing batch 221/633
# Getting genres for: Bored by Billie Eilish
# Getting genres for: Softcore by The Neighbourhood
# Getting genres for: I Lost My Mind by Super Pipo
#
# Processing batch 222/633
# Getting genres for: Atlantis by Seafret
# Getting genres for: I Love You So by The Walters
# Getting genres for: Romantic Homicide by d4vd
#
# Processing batch 223/633
# Getting genres for: You Get Me So High by The Neighbourhood
# Getting genres for: Brooklyn Baby by Lana Del Rey
# Getting genres for: Runaway by AURORA
#
# Processing batch 224/633
# Getting genres for: Moral of the Story by Ashe
# Getting genres for: Water Fountain by Alec Benjamin
# Getting genres for: Mind Over Matter by Young the Giant
#
# Processing batch 225/633
# Getting genres for: Apocalypse by Cigarettes After Sex
# Getting genres for: idfc by blackbear
# Getting genres for: The Beach by The Neighbourhood
#
# Processing batch 226/633
# Getting genres for: Always Forever by Cults
# Getting genres for: Cigarette Daydreams by Cage The Elephant
# Getting genres for: Cry by Cigarettes After Sex
#
# Processing batch 227/633
# Getting genres for: Those Eyes by New West
# Getting genres for: Something About You by Eyedress
# Getting genres for: Notion by The Rare Occasions
#
# Processing batch 228/633
# Getting genres for: Memories by Conan Gray
# Getting genres for: Lights Are On by Tom Rosenthal
# Getting genres for: Blue Hair by TV Girl
#
# Processing batch 229/633
# Getting genres for: One More Hour by Tame Impala
# Getting genres for: worldstar money (interlude) by Joji
# Getting genres for: Let It Happen by Tame Impala
#
# Processing batch 230/633
# Getting genres for: Stargirl Interlude by The Weeknd
# Getting genres for: The Less I Know The Better by Tame Impala
# Getting genres for: Looking Out for You by Joy Again
#
# Processing batch 231/633
# Getting genres for: Borderline by Tame Impala
# Getting genres for: Cigarettes out the Window by TV Girl
# Getting genres for: Loverboy by A-Wall
#
# Processing batch 232/633
# Getting genres for: Bubble Gum by Clairo
# Getting genres for: Are You Bored Yet? (feat. Clairo) by Wallows
# Getting genres for: Mrs Magic by Strawberry Guy
#
# Processing batch 233/633
# Getting genres for: Not Allowed by TV Girl
# Getting genres for: Come a Little Closer by Cage The Elephant
# Getting genres for: Kids by Current Joys
#
# Processing batch 234/633
# Getting genres for: Sofia by Clairo
# Getting genres for: New Person, Same Old Mistakes by Tame Impala
# Getting genres for: New Flesh by Current Joys
#
# Processing batch 235/633
# Getting genres for: Washing Machine Heart by Mitski
# Getting genres for: Money by The Drums
# Getting genres for: For the First Time by Mac DeMarco
#
# Processing batch 236/633
# Getting genres for: rises the moon by Liana Flores
# Getting genres for: Eventually by Tame Impala
# Getting genres for: Show Me How by Men I Trust
#
# Processing batch 237/633
# Getting genres for: Take A Slice by Glass Animals
# Getting genres for: Knee Socks by Arctic Monkeys
# Getting genres for: No Surprises by Radiohead
#
# Processing batch 238/633
# Getting genres for: Little Dark Age by MGMT
# Getting genres for: Cry Baby by The Neighbourhood
# Getting genres for: Girl of My Dreams by Guti
#
# Processing batch 239/633
# Getting genres for: Sports by Beach Bunny
# Getting genres for: welcome and goodbye by Dream, Ivory
# Getting genres for: Pretty Boy by The Neighbourhood
#
# Processing batch 240/633
# Getting genres for: Fear by Current Joys
# Getting genres for: Fool by Frankie Cosmos
# Getting genres for: First Love/Late Spring by Mitski
#
# Processing batch 241/633
# Getting genres for: Les by Childish Gambino
# Getting genres for: Sparks by Coldplay
# Getting genres for: The Loser by Verzache
#
# Processing batch 242/633
# Getting genres for: No Other Heart by Mac DeMarco
# Getting genres for: Flaming Hot Cheetos by Clairo
# Getting genres for: Rhinestone Eyes by Gorillaz
#
# Processing batch 243/633
# Getting genres for: Melting by Kali Uchis
# Getting genres for: Heartbeat by Childish Gambino
# Getting genres for: Cola by CamelPhat
#
# Processing batch 244/633
# Getting genres for: Sonnentanz - Sun Don't Shine by Klangkarussell
# Getting genres for: Adieu by Tchami
# Getting genres for: Heal Me - Biscits Remix by FARR
#
# Processing batch 245/633
# Getting genres for: Touch Me by Rui Da Silva
# Getting genres for: En Su Lugar by Alé Kumá
# Getting genres for: Heartbeat by Claptone
#
# Processing batch 246/633
# Getting genres for: Glue by BICEP
# Getting genres for: Touch Me - PAX & Rui Da Silva Version by PAX
# Getting genres for: Anchor Point by Ahmed Spins
#
# Processing batch 247/633
# Getting genres for: Billie (loving arms) by Fred again..
# Getting genres for: adore u by Fred again..
# Getting genres for: Delilah (pull me out of this) by Fred again..
#
# Processing batch 248/633
# Getting genres for: The Power by Duke Dumont
# Getting genres for: leavemealone by Fred again..
# Getting genres for: You & Me - Flume Remix by Disclosure
#
# Processing batch 249/633
# Getting genres for: Marea (we’ve lost dancing) by Fred again..
# Getting genres for: Who Loves The Sun feat. Jo.Ke - Edit by Nu
# Getting genres for: places to be by Fred again..
#
# Processing batch 250/633
# Getting genres for: La Danza by John Summit
# Getting genres for: Famax - Edit by RAFFA GUIDO
# Getting genres for: ten by Fred again..
#
# Processing batch 251/633
# Getting genres for: Lauren (I Can't Stay Forever) by Oden & Fatzo
# Getting genres for: Mwaki by Zerb
# Getting genres for: Feel So Close - Radio Edit by Calvin Harris
#
# Processing batch 252/633
# Getting genres for: Tocame by Sak Noel
# Getting genres for: Si Ai - Marshmello & UKAY Remix by Tayna
# Getting genres for: Blame (feat. John Newman) by Calvin Harris
#
# Processing batch 253/633
# Getting genres for: Memories (feat. Kid Cudi) by David Guetta
# Getting genres for: Relax My Eyes by ANOTR
# Getting genres for: Nanana Vs Cola by frxzen
#
# Processing batch 254/633
# Getting genres for: It's Not Right - Radio Edit by Gianni Romano
# Getting genres for: Where Are You Now by Lost Frequencies
# Getting genres for: Fake ID (Coke & Rum Remix) by Riton
#
# Processing batch 255/633
# Getting genres for: Everywhere by Babsy.
# Getting genres for: Rain In Ibiza by Felix Jaehn
# Getting genres for: I Only Smoke When I Drink by nimino
#
# Processing batch 256/633
# Getting genres for: World Hold On (Children Of The Sky) - FISHER Rework by Bob Sinclar
# Getting genres for: Karibu by WITH U
# Getting genres for: Sweet Disposition - John Summit & Silver Panda Remix by The Temper Trap
#
# Processing batch 257/633
# Getting genres for: Sauti by Francis Mercier
# Getting genres for: Samba by YouNotUs
# Getting genres for: Yamore by MoBlack
#
# Processing batch 258/633
# Getting genres for: Sideways by Gordo
# Getting genres for: Sugar by YA NINA
# Getting genres for: Bunu Sana Demiştim (Disco Tarantula Remix) by Tuğçe Şenoğul
#
# Processing batch 259/633
# Getting genres for: Famax by RAFFA GUIDO
# Getting genres for: Allies by Mahmut Orhan
# Getting genres for: Bad Memories by MEDUZA
#
# Processing batch 260/633
# Getting genres for: Miss You by Nu Aspect
# Getting genres for: Another Love - Tiësto Remix by Tom Odell
# Getting genres for: Catch & Release - Deepend Remix by Matt Simons
#
# Processing batch 261/633
# Getting genres for: Secrets by Tudor
# Getting genres for: Losing Myself by Portugal Sunset
# Getting genres for: Ocean Pass by just here.
#
# Processing batch 262/633
# Getting genres for: Off Limits by Welcome2hills
# Getting genres for: Keep It Simple by Audrey Floyd
# Getting genres for: Your Touch by Why U So
#
# Processing batch 263/633
# Getting genres for: Follow The Vibe by Portugal Sunset
# Getting genres for: Paris In The Rain by PLVTO
# Getting genres for: Wait All Night by Lane Boy
#
# Processing batch 264/633
# Getting genres for: Sirens by Dallerium
# Getting genres for: Body by Nathan C
# Getting genres for: Distraction by Nu Aspect
#
# Processing batch 265/633
# Getting genres for: Running Back to You by Astrality
# Getting genres for: No Sense by Tobtok
# Getting genres for: Why Does My Heart Feel So Bad? ft. Moby by AVALAN ROKSTON
#
# Processing batch 266/633
# Getting genres for: Talk To Me by DRAY
# Getting genres for: Reminds Me Of You by Hii Spirits
# Getting genres for: In Your Arms by Shift K3Y
#
# Processing batch 267/633
# Getting genres for: Don't (Fall in Love) by Just Kiddin
# Getting genres for: Show Me by JLV
# Getting genres for: Are You Feeling It Too? by Gorgon City
#
# Processing batch 268/633
# Getting genres for: Mwaki - Tiësto's VIP Mix by Zerb
# Getting genres for: Out of My Head by Jack Wins
# Getting genres for: Bonfire by Tudor
#
# Processing batch 269/633
# Getting genres for: Turn On The Lights again.. (feat. Future) by Fred again..
# Getting genres for: In My Mind by Lavern
# Getting genres for: Glue x How Deep Is Your Love - Remake Cover by renewwed
#
# Processing batch 270/633
# Getting genres for: Baby Don't Hurt Me by David Guetta
# Getting genres for: Baby again.. by Fred again..
# No results found for Baby again.. by Fred again..
# Getting genres for: Me (heavy) by Fred again..
#
# ...
# Getting genres for: Sana Ne Kime Ne by Ajda Pekkan
#
# Processing batch 542/633
# Getting genres for: Aşkın Ateşi by Hande Yener
# Getting genres for: Yalancı Bahar by Aşkın Nur Yengi
# Getting genres for: Kim Ne Derse Desin by Ajda Pekkan
#
# Processing batch 543/633
# Getting genres for: Köle by Aydın Kurtoğlu
# Getting genres for: Gittiğinde by Göksel
# Getting genres for: Dudak by EDIS
#
# Processing batch 544/633
# Getting genres for: Ara Sıcak by Ajda Pekkan
# Getting genres for: Doktor by Kenan Doğulu
# Getting genres for: Murder on My Mind by YNW Melly
#
# Processing batch 545/633
# Getting genres for: Desert Woman by ZHU
# Getting genres for: Waters of Monaco by ZHU
# Getting genres for: NIGHTS LIKE THIS PT 2 by The Kid LAROI
#
# Processing batch 546/633
# Getting genres for: Provocateur by ZHU
# Getting genres for: Chasing Marrakech by ZHU
# Getting genres for: Desire - Solomun Remix (Edit) by Bob Moses
#
# Processing batch 547/633
# Getting genres for: My Life - Klangstof Remix by ZHU
# Getting genres for: Desire - Solomun Remix by Bob Moses
# Getting genres for: In the Morning - Tom Glass Remix by ZHU
#
# Processing batch 548/633
# Getting genres for: Days Before Grace by ZHU
# Getting genres for: Revelations by ZHU
# Getting genres for: VISA by ZHU
#
# Processing batch 549/633
# Getting genres for: Cola - ZHU Remix by CamelPhat
# Getting genres for: Lil Mama by partywithray
# Getting genres for: Never Give Up - ZHU Remix by Mathame
#
# Processing batch 550/633
# Getting genres for: Neverender by Justice
# Getting genres for: Drowning by ZHU
# Getting genres for: There's a Reason You're Alone by Vincemp3
#
# Processing batch 551/633
# Getting genres for: PAPARAZZI by UZI
# Getting genres for: Soaked - Slowed Down by Shy Smith
# Getting genres for: Kadıköy Kızı by Yüzyüzeyken Konuşuruz
#
# Processing batch 552/633
# Getting genres for: Uykusuz ve Dengesiz by Yüzyüzeyken Konuşuruz
# Getting genres for: Onlar da Yansın by Yüzyüzeyken Konuşuruz
# Getting genres for: No Wind Resistance! by Kinneret
#
# Processing batch 553/633
# Getting genres for: 60 Seconds by Community Sinners
# Getting genres for: yok muydu vaktin bana by Russian Children
# Getting genres for: Klişe Masallar by Güneş
#
# Processing batch 554/633
# Getting genres for: Mektup by Motive
# Getting genres for: Gel Bana by Mustafa Sandal
# Getting genres for: Delgeç by Şebnem Ferah
#
# Processing batch 555/633
# Getting genres for: Yeniden by Yalın
# Getting genres for: Give It To Me (Sped Up) by Way 2 Fast
# Getting genres for: Perreo by Quentro
#
# Processing batch 556/633
# Getting genres for: La Verdolaga (feat. Totó La Momposina) by HUGEL
# Getting genres for: Papi (Bhabi) by Eden Shalev
# Getting genres for: Nothing On Me by Maz
#
# Processing batch 557/633
# Getting genres for: Makeda by Alice DiMar
# Getting genres for: Andalucia by HUGEL
# Getting genres for: Baiana - Radio Edit by Space Motion
#
# Processing batch 558/633
# Getting genres for: Hey Hey - Jack Back Remix by Dennis Ferrer
# Getting genres for: Ode Ireti - Nitefreak Remix by &friends
# Getting genres for: Yarı Çıplak by Gülben Ergen
#
# Processing batch 559/633
# Getting genres for: Tatlıyla Balla by Yalın
# Getting genres for: Chicago Freestyle (feat. Giveon) by Drake
# Getting genres for: Myron by Lil Uzi Vert
#
# Processing batch 560/633
# Getting genres for: Hikaye Bitti Çoktan by Kayra
# Getting genres for: Forever (feat. Malou & Yuna) by HUGEL
# Getting genres for: Testarossa Music by ZHU
#
# Processing batch 561/633
# Getting genres for: Rekor by Demet Akalın
# Getting genres for: Kyle (i found you) by Fred again..
# Getting genres for: Massive by Drake
#
# Processing batch 562/633
# Getting genres for: Drums (Feat. Kim Petras) by James Hype
# Getting genres for: No More (feat. ZHU) by DJ Snake
# Getting genres for: Sundream by RÜFÜS DU SOL
#
# Processing batch 563/633
# Getting genres for: Underwater by RÜFÜS DU SOL
# Getting genres for: Light it Up - Holly Remix by ZHU
# Getting genres for: Gidecek Yerim Mi Var by Emre Altuğ
#
# Processing batch 564/633
# Getting genres for: Bum Bum Tam Tam by MC Fioti
# Getting genres for: Rayheen Nesshar - Bum Bum by Mohamed Ramadan
# Getting genres for: PRIDE. by Kendrick Lamar
#
# Processing batch 565/633
# Getting genres for: Melt by Duke Dumont
# Getting genres for: Somebody (2024) by Gotye
# Getting genres for: JUVENILE by The Blaze
#
# Processing batch 566/633
# Getting genres for: Alegria by ARYMÉ
# Getting genres for: Danielle (smile on my face) by Fred again..
# Getting genres for: How You Feel (Ft. Leven Kali) by ANOTR
#
# Processing batch 567/633
# Getting genres for: Father Stretch My Hands Pt. 1 by Kanye West
# Getting genres for: MIDDLE CHILD by J. Cole
# Getting genres for: Gang Baby by NLE Choppa
#
# Processing batch 568/633
# Getting genres for: Chihiro by Gravagerz
# Getting genres for: Kisses (feat. bbyclose) by BL3SS
# Getting genres for: ecstacy (slowed) by SUICIDAL-IDOL
#
# Processing batch 569/633
# Getting genres for: Cola - Sped Up Version by sped up nightcore
# Getting genres for: In My Mind by Dynoro
# Getting genres for: Baby Girl by Disco Lines
#
# Processing batch 570/633
# Getting genres for: Rainfall (Praise You) by Tom Santa
# Getting genres for: Little Things x Gypsy Woman - L BEATS MASHUP by Jorja Smith
# Getting genres for: I Got Summer On My Mind by Jay Dunham
#
# Processing batch 571/633
# Getting genres for: COUNTING STARS DRILL SPED UP by DRILL GATES
# Getting genres for: Afraid To Feel by LF SYSTEM
# Getting genres for: Heaven Takes You Home (feat. Connie Constance) by Swedish House Mafia
#
# Processing batch 572/633
# Getting genres for: Heads Will Roll - A-Trak Remix Radio Edit by Yeah Yeah Yeahs
# Getting genres for: Superlike by Crunkz
# Getting genres for: Move Your Body by Öwnboss
#
# Processing batch 573/633
# Getting genres for: Belly Dancer by Imanbek
# Getting genres for: S&M by Rihanna
# Getting genres for: Pump It Up by Endor
#
# Processing batch 574/633
# Getting genres for: In The Dark by Jend
# Getting genres for: Paint by Jones Meadow
# Getting genres for: In Brevi by Valante
#
# Processing batch 575/633
# Getting genres for: Touch by Starioh
# Getting genres for: Teenage by Peed Hus
# Getting genres for: body atlas by Parker Son
#
# Processing batch 576/633
# Getting genres for: Across The Field by Naomi Boko
# Getting genres for: Less Is More by Comfykids
# Getting genres for: Floating by Ensidya
#
# Processing batch 577/633
# Getting genres for: Baia do Sancho by Slow Reveal
# Getting genres for: Instinct by Lumin
# Getting genres for: Desire Whisperer by Pink Beaches
#
# Processing batch 578/633
# Getting genres for: Heavy Wish by 9Fivey
# Getting genres for: Orange Juice by Chairten
# Getting genres for: Magic Island by Matobolo
#
# Processing batch 579/633
# Getting genres for: All Good by Mikayl Blu
# Getting genres for: Coastal Whisper by Closest Cloud
# Getting genres for: ELLERİM BOŞ by M Lisa
#
# Processing batch 580/633
# Getting genres for: 2017 by M Lisa
# Getting genres for: Aşk Olsun - Speed Up by cakal
# Getting genres for: AÇ YARALAR by M Lisa
#
# Processing batch 581/633
# Getting genres for: Serbest Stil 3 by Cozulemez
# No results found for Serbest Stil 3 by Cozulemez
# Getting genres for: Right Days by Soft Sea
# Getting genres for: finish by flooww
#
# Processing batch 582/633
# Getting genres for: Balearic Dream by Gueves
# Getting genres for: Amnesia by Tendoi
# Getting genres for: Spinn by Off Grand
#
# Processing batch 583/633
# Getting genres for: Bonez by Dahtona
# Getting genres for: Soil by Bush Lily
# Getting genres for: Morning Dew by Undefined Space
#
# Processing batch 584/633
# Getting genres for: Wet Bravado by R Y K
# Getting genres for: Afterbeach by Flamentone
# Getting genres for: Almannagjá by West & Zander
#
# Processing batch 585/633
# Getting genres for: Torn by Deeter K
# Getting genres for: One for the Road by Mads Nielsen Stolt
# Getting genres for: Antibes (Edit) by Leo Lemón
#
# Processing batch 586/633
# Getting genres for: Iconic by Monic
# Getting genres for: Afterhours by Distoboy
# Getting genres for: Vienna by KD Simon
#
# Processing batch 587/633
# Getting genres for: Hugger by Zazzo
# Getting genres for: joy love by Goose Groovy
# Getting genres for: Boats by Penga Scain
#
# Processing batch 588/633
# Getting genres for: Yin Yan Tonic by Son-us
# Getting genres for: Defenition by Cray Barnes
# Getting genres for: Right Direction by Bending Lights
#
# Processing batch 589/633
# Getting genres for: Kenaya by Saint Haux
# Getting genres for: Tea Time by GRNY
# Getting genres for: move over by sugar namnam
#
# Processing batch 590/633
# Getting genres for: Aspects by Deeter K
# Getting genres for: New Horizon by rigii
# Getting genres for: Red Light Green Light - For Club Play Only, Pt. 6 by Duke Dumont
#
# Processing batch 591/633
# Getting genres for: crusade by Cloode
# Getting genres for: Just Friends by Hayden James
# Getting genres for: Higher Power - ZHU Remix by Coldplay
#
# Processing batch 592/633
# Getting genres for: Just A Lover by Hayden James
# Getting genres for: EYES by The Blaze
# Getting genres for: Veridis Quo by Daft Punk
#
# Processing batch 593/633
# Getting genres for: Horizon (Japan CD) by Daft Punk
# Getting genres for: Lose Yourself to Dance (feat. Pharrell Williams) by Daft Punk
# Getting genres for: GL (Early Take) [feat. Pharrell Williams and Nile Rodgers] by Daft Punk
#
# Processing batch 594/633
# Getting genres for: Digital Love by Daft Punk
# Getting genres for: Prime (2012 Unfinished) by Daft Punk
# Getting genres for: Infinity Repeating (2013 Demo) [feat. Julian Casablancas+The Voidz] by Daft Punk
#
# Processing batch 595/633
# Getting genres for: Arena by Daft Punk
# Getting genres for: Da Funk by Daft Punk
# Getting genres for: End of Line by Daft Punk
#
# Processing batch 596/633
# Getting genres for: Voyager by Daft Punk
# Getting genres for: AMCAS RMX by Batuflex
# Getting genres for: KHRBR by Ati242
#
# Processing batch 597/633
# Getting genres for: Sesinde Aşk Var by Yalın
# Getting genres for: Her Nerdeysen by Ati242
# Getting genres for: Sönen Sigaralar by Ati242
#
# Processing batch 598/633
# Getting genres for: Kalbim Yanımda by Ati242
# Getting genres for: Telefon by Ati242
# Getting genres for: levitation by Aaron Hibell
#
# Processing batch 599/633
# Getting genres for: la danse by berlioz
# Getting genres for: Blossom by Izzamuzzic
# Getting genres for: Midnight - Original Mix by Lane 8
#
# Processing batch 600/633
# Getting genres for: Bloodflow by Grandbrothers
# Getting genres for: Kadehimi Boş Bırakma by Ezhel
# Getting genres for: Beng ü Bade by Ezhel
#
# Processing batch 601/633
# Getting genres for: Şehrimin Tadı by Ezhel
# Getting genres for: Nefret by Ezhel
# Getting genres for: Alışamadım by Ezhel
#
# Processing batch 602/633
# Getting genres for: Hayır by Ezhel
# Getting genres for: Benim Derdim by Ezhel
# Getting genres for: İyi Bil by Ezhel
#
# Processing batch 603/633
# Getting genres for: Pencerende by Ezhel
# Getting genres for: Feel It Still - ZHU Remix by Portugal. The Man
# Getting genres for: Houdini by Dua Lipa
#
# Processing batch 604/633
# Getting genres for: One Kiss (with Dua Lipa) - ZHU Remix by Calvin Harris
# Getting genres for: Cold Heart - PNAU Remix by Elton John
# Getting genres for: Man's First Inhibition (feat. Kidd Keem) by NGHTMRE
#
# Processing batch 605/633
# Getting genres for: Doin' it Right (feat. Panda Bear) by Daft Punk
# Getting genres for: Tutamıyorum Zamanı by Müslüm Gürses
# Getting genres for: Sahici by Bengü
#
# Processing batch 606/633
# Getting genres for: Discovery by Chico Rocket
# Getting genres for: under the palm by Mikayl Blu
# Getting genres for: Clearance by Dan Awy
#
# Processing batch 607/633
# Getting genres for: eastland by papi.
# Getting genres for: Summer Like Before by Vee Jay
# Getting genres for: Rehine by Enjoy Banker
#
# Processing batch 608/633
# Getting genres for: Moody by Paula Nash
# Getting genres for: We are all set by Sunset-buff
# Getting genres for: FlipFlops by Kayyyy
#
# Processing batch 609/633
# Getting genres for: Icebreaker by Thoinas
# Getting genres for: Vows by Milli V
# Getting genres for: Mazal by Milous
#
# Processing batch 610/633
# Getting genres for: Solar System by Palm 3s
# Getting genres for: SRY by Twelwe
# Getting genres for: Aganu by SCRP
#
# Processing batch 611/633
# Getting genres for: C'mon Weekend by bombergirl
# Getting genres for: Amalfi by Naupaka
# Getting genres for: Man of her dreams by Phoenix Rouge
#
# Processing batch 612/633
# Getting genres for: Mellow Trouble by Sin.Clare
# Getting genres for: Parasol by Zeyn Mont
# Getting genres for: Été by Cámille
#
# Processing batch 613/633
# Getting genres for: Oh My by Larry Poppinz
# Getting genres for: Sker by Valante
# Getting genres for: mirage by sir bennett
#
# Processing batch 614/633
# Getting genres for: Buller by Hula Hoops
# Getting genres for: No Trip by Young Community
# Getting genres for: Suede by Alexis Dex
#
# Processing batch 615/633
# Getting genres for: 86 by Vynlsm
# Getting genres for: SPF by Jasise
# Getting genres for: Summer Days by Vee Jay
#
# Processing batch 616/633
# Getting genres for: Green Tea by RA DAR
# Getting genres for: One More Time by bonaira
# Getting genres for: Fool Me by Bear Frantz
#
# Processing batch 617/633
# Getting genres for: Cruising by Lou Kil
# Getting genres for: Il Mondriano by papi.
# Getting genres for: Passage by Ben Travel
#
# Processing batch 618/633
# Getting genres for: Reach by Jox Talay
# Getting genres for: Sun In Seoul by Midnight Side Eye
# Getting genres for: Falling Faster by Niriko
#
# Processing batch 619/633
# Getting genres for: Ses Salines by VILT
# Getting genres for: Summertide by Edward The Eagle
# Getting genres for: Testarossa by Slow Burn
#
# Processing batch 620/633
# Getting genres for: Snoozing by Yavuz Grill
# Getting genres for: Suamalie by Slashio
# Getting genres for: Ripples of Relaxation by Lian Leom
#
# Processing batch 621/633
# Getting genres for: Deepmind by Suuunday
# Getting genres for: Gran Via by Sobbel Sosch
# Getting genres for: Femme by Lndoner
#
# Processing batch 622/633
# Getting genres for: leading up by SGT DUST
# Getting genres for: Get Some by Soul to Speak
# Getting genres for: Morning Light by HillBlindz
#
# Processing batch 623/633
# Getting genres for: Blend by Hibiscus
# Getting genres for: east of the island by Greene Labyrinth
# Getting genres for: Blue Gold by Far Orange
#
# Processing batch 624/633
# Getting genres for: One Day by GIM GAM
# Getting genres for: Sunset by Rōsu
# Getting genres for: it is by Hello Papyrus
#
# Processing batch 625/633
# Getting genres for: For The First Time by Slow
# Getting genres for: Kap Verde by Uncle Feaster
# Getting genres for: Heads Up by Ori Kul
#
# Processing batch 626/633
# Getting genres for: Sunny Day by Chairten
# Getting genres for: Yearn by West & Zander
# Getting genres for: Unhappy Alien by Not Tudor
#
# Processing batch 627/633
# Getting genres for: For Nothing by KD Simon
# Getting genres for: Mountain High by liily day
# Getting genres for: Zero by Pink Lotus
#
# Processing batch 628/633
# Getting genres for: Look At The Stars by Carinth
# Getting genres for: Staycation by pxp pxp
# Getting genres for: Domino Effect by Camisade
#
# Processing batch 629/633
# Getting genres for: Timid Space by Yamouss
# Getting genres for: Sona by Valante
# Getting genres for: deep feelings by Jaake Alsonn
#
# Processing batch 630/633
# Getting genres for: Hauted House by RODUT
# Getting genres for: forward thinking by Landayn
# Getting genres for: Bit of Window by Conte Prad
#
# Processing batch 631/633
# Getting genres for: Eyes on Me by André Aguado
# Getting genres for: You Name It by PeachPuff
# Getting genres for: Day Drinks by Sonic
#
# Processing batch 632/633
# Getting genres for: SHE by The Blaze
# Getting genres for: Lose Control by James Hype
# Getting genres for: Short Circuit by Daft Punk
#
# Successfully processed 1572 tracks
#
# Genre-Spending Analysis Results:
#
# Total genres analyzed: 170
#
# Top positive correlations:
#              genre  correlation  avg_spending
# 71   trap italiana         0.92        405.74
# 119         reggae         0.85        343.00
# 120  reggae fusion         0.84        184.17
# 62     italo dance         0.77       -731.13
# 112    florida rap         0.66       -132.69
#
# Top negative correlations:
#                 genre  correlation  avg_spending
# 135   electronic trap        -0.89       -798.75
# 87   huzunlu sarkilar        -0.75         95.92
# 55            brostep        -0.69        511.84
# 113         hip house        -0.64        402.98
# 58          dutch edm        -0.59        389.80

# %%
# [Cell 1] - Import required libraries
import pandas as pd
import json
import matplotlib.pyplot as plt
import seaborn as sns
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import time
from datetime import datetime
from urllib3.util.retry import Retry
from requests.adapters import HTTPAdapter
import requests
import numpy as np

class SpotifyGenreAnalyzer:
    def __init__(self, client_id, client_secret):
        # Configure retry strategy
        retry_strategy = Retry(
            total=5,
            backoff_factor=1,
            status_forcelist=[429, 500, 502, 503, 504]
        )
        adapter = HTTPAdapter(max_retries=retry_strategy)
        
        # Initialize Spotify client with retry strategy
        self.client_credentials_manager = SpotifyClientCredentials(
            client_id=client_id,
            client_secret=client_secret
        )
        self.sp = spotipy.Spotify(
            client_credentials_manager=self.client_credentials_manager,
            requests_timeout=30
        )
        self.sp._session.mount("https://", adapter)
        
        # Initialize cache for genres
        self.genre_cache = {}
        
    def get_track_genres(self, track_name, artist_name):
        """Get genre information with caching and error handling"""
        cache_key = f"{artist_name}:{track_name}"
        
        # Check cache first
        if cache_key in self.genre_cache:
            return self.genre_cache[cache_key]
        
        try:
            # Clean track name and artist name
            track_name = track_name.replace('%', '')
            artist_name = artist_name.replace('%', '')
            
            # Search for the track
            results = self.sp.search(
                q=f"track:{track_name} artist:{artist_name}",
                type='track',
                limit=1
            )
            
            if not results['tracks']['items']:
                print(f"No results found for {track_name} by {artist_name}")
                return None
            
            # Get artist ID and details
            artist_id = results['tracks']['items'][0]['artists'][0]['id']
            artist = self.sp.artist(artist_id)
            genres = artist['genres']
            
            # Cache the result
            self.genre_cache[cache_key] = genres
            print(f"Found genres for {artist_name}: {genres}")
            
            return genres
            
        except Exception as e:
            if "429" in str(e):
                print("Rate limit hit, waiting 30 seconds...")
                time.sleep(30)
                return self.get_track_genres(track_name, artist_name)
            print(f"Error getting genres for {track_name} by {artist_name}: {str(e)}")
            return None
    
    def process_streaming_history(self):
        """Process streaming history with optimized batch processing"""
        # Load streaming history
        with open('StreamingHistory_music_2.json', 'r', encoding='utf-8') as f:
            spotify_data = json.load(f)
        
        # Convert to DataFrame and get unique tracks
        df = pd.DataFrame(spotify_data)
        df['msPlayed'] = pd.to_numeric(df['msPlayed'])
        
        # Sort by most played and get unique tracks
        track_stats = df.groupby(['trackName', 'artistName'])['msPlayed'].sum().reset_index()
        track_stats = track_stats.sort_values('msPlayed', ascending=False)
        
        # Process tracks
        processed_tracks = []
        
        for i, row in track_stats.iterrows():
            print(f"\nProcessing track {i+1}/{len(track_stats)}")
            genres = self.get_track_genres(row['trackName'], row['artistName'])
            
            if genres:
                processed_tracks.append({
                    'artist': row['artistName'],
                    'track': row['trackName'],
                    'genres': genres,
                    'total_ms': row['msPlayed']
                })
            
            # Save progress after each track
            if (i + 1) % 10 == 0:
                with open('genre_progress.json', 'w', encoding='utf-8') as f:
                    json.dump(processed_tracks, f, ensure_ascii=False, indent=2)
            
            # Controlled delay
            time.sleep(1)
        
        # Final save
        with open('genre_progress.json', 'w', encoding='utf-8') as f:
            json.dump(processed_tracks, f, ensure_ascii=False, indent=2)
        
        return processed_tracks

def main():
    # Initialize analyzer with your credentials
    analyzer = SpotifyGenreAnalyzer(
        client_id='82d3f15f60ee4fd08d64f23a2b2bd8de',
        client_secret='5b892d88f74a4465af1a66d81c571d15'
    )
    
    try:
        # Process streaming history
        processed_tracks = analyzer.process_streaming_history()
        print(f"\nSuccessfully processed {len(processed_tracks)} tracks")
        
    except Exception as e:
        print(f"An error occurred in main execution: {str(e)}")
        raise

if __name__ == "__main__":
    main()
# Out:
# Processing track 398/1896
# Found genres for Murat Dalkılıç: ['turkish pop']
#
# Processing track 1619/1896
# Found genres for Fred again..: ['edm', 'pop dance', 'progressive electro house']
#
# Processing track 1430/1896
# Found genres for Murat Dalkılıç: ['turkish pop']
#
# Processing track 1339/1896
# Found genres for Bengü: ['turkish pop']
#
# Processing track 1853/1896
# Found genres for niteboi: ['drift phonk']
#
# Processing track 849/1896
# Found genres for Hande Yener: ['turkish pop']
#
# Processing track 1733/1896
# Found genres for AFRO: []
#
# Processing track 1887/1896
# Found genres for Sezen Aksu: ['turkish pop']
#
# Processing track 585/1896
# Found genres for ZHU: ['edm', 'electro house']
#
# Processing track 258/1896
# Found genres for Ozan Çolakoğlu: ['turkish pop']
#
# Processing track 257/1896
# Found genres for Teoman: ['turkish rock']
#
# Processing track 1444/1896
# Found genres for Yalın: ['turkish pop']
#
# Processing track 125/1896
# Found genres for Serdar Ortaç: ['turkish pop']
#
# Processing track 1622/1896
# Found genres for Kenan Doğulu: ['turkish pop']
#
# Processing track 649/1896
# Found genres for Hande Yener: ['turkish pop']
#
# Processing track 124/1896
# Found genres for Aleyna Tilki: ['turkish pop']
#
# Processing track 1747/1896
# Found genres for Ufo361: ['german cloud rap', 'german hip hop']
#
# Processing track 695/1896
# Found genres for Shakira: ['colombian pop', 'dance pop', 'latin pop', 'pop']
#
# Processing track 296/1896
# Found genres for maNga: ['turkish rock']
#
# Processing track 681/1896
# Found genres for Ati242: ['turkish hip hop']
#
# Processing track 1294/1896
# Found genres for Twenty One Pilots: ['modern rock', 'pop', 'pov: indie', 'rock']
#
# Processing track 1468/1896
# Found genres for ZHU: ['edm', 'electro house']
#
# Processing track 1111/1896
# Found genres for J. Cole: ['conscious hip hop', 'hip hop', 'north carolina hip hop', 'rap']
#
# Processing track 1221/1896
# Found genres for Quentro: []
#
# Processing track 1737/1896
# Found genres for Gülben Ergen: ['arabesk', 'turkish pop']
#
# Processing track 829/1896
# Found genres for Derya Uluğ: ['turkish pop']
#
# Processing track 1010/1896
# Found genres for Motive: ['turkish hip hop', 'turkish trap']
#
# Processing track 948/1896
# Found genres for Adele: ['british soul', 'pop', 'pop soul', 'uk pop']
#
# Processing track 1744/1896
# Found genres for Elanur: ['turkce kadin rap', 'turkish hip hop']
#
# Processing track 659/1896
# Found genres for Duman: ['anadolu rock', 'karadeniz turkuleri', 'turkish alternative', 'turkish alternative rock', 'turkish rock']
#
# Processing track 595/1896
# Found genres for ZHU: ['edm', 'electro house']
#
# Processing track 190/1896
# Found genres for Ozan Çolakoğlu: ['turkish pop']
#
# Processing track 947/1896
# Found genres for David Guetta: ['big room', 'dance pop', 'edm', 'pop', 'pop dance']
#
# Processing track 479/1896
# Found genres for Ndotz: ['chill drill']
#
# Processing track 1447/1896
# Found genres for Pato Shoucair: []
#
# Processing track 116/1896
# Found genres for Serdar Ortaç: ['turkish pop']
#
# Processing track 1749/1896
# Found genres for Yalın: ['turkish pop']
#
# Processing track 1594/1896
# Found genres for Hozier: ['irish singer-songwriter', 'modern rock', 'pop', 'pov: indie']
#
# Processing track 1423/1896
# Found genres for Shy Smith: []
#
# Processing track 1706/1896
# Found genres for Chris Isaak: ['mellow gold']
#
# Processing track 836/1896
# Found genres for Sedef Sebüktekin: ['turkish alt pop', 'turkish rock']
#
# Processing track 844/1896
# Found genres for Yalın: ['turkish pop']
#
# Processing track 770/1896
# Found genres for ZHU: ['edm', 'electro house']
#
# Processing track 1412/1896
# Found genres for Ash: ['arab electronic']
#
# Processing track 288/1896
# Found genres for Kanye West: ['chicago rap', 'hip hop', 'rap']
#
# Processing track 128/1896
# Found genres for Serdar Ortaç: ['turkish pop']
#
# Processing track 633/1896
# Found genres for Serdar Ortaç: ['turkish pop']
#
# Processing track 850/1896
# Found genres for M Lisa: []
#
# Processing track 1016/1896
# Found genres for Tepki: ['turkish hip hop', 'turkish trap']
#
# Processing track 1135/1896
# Found genres for Duke Dumont: ['edm', 'house', 'pop dance', 'progressive house', 'uk dance']
#
# Processing track 1489/1896
# Found genres for Jaden: ['pop rap', 'rap']
#
# Processing track 1351/1896
# Found genres for Yıldız Tilbe: ['turkish pop']
#
# Processing track 988/1896
# Found genres for Fred again..: ['edm', 'house', 'stutter house']
#
# Processing track 1840/1896
# Found genres for 21 Savage: ['atl hip hop', 'hip hop', 'rap']
#
# Processing track 1891/1896
# Found genres for Rauf & Faik: ['russian pop']
#
# Processing track 730/1896
# Found genres for Duke Dumont: ['edm', 'house', 'pop dance', 'progressive house', 'uk dance']
#
# Processing track 654/1896
# Found genres for The Game: ['detroit hip hop', 'gangster rap', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap']
#
# Processing track 256/1896
# Found genres for Şebnem Ferah: ['turkish pop', 'turkish rock']
#
# Processing track 868/1896
# Found genres for Yalın: ['turkish pop']
#
# Processing track 1279/1896
# Found genres for The Neighbourhood: ['modern alternative rock', 'modern rock', 'pop']
#
# Processing track 1302/1896
# Found genres for Vance Joy: ['folk-pop', 'modern rock']
#
# Processing track 180/1896
# Found genres for Tinlicker: ['melodic house']
#
# Processing track 608/1896
# Found genres for BICEP: ['ambient house', 'electronica']
#
# Processing track 1070/1896
# Found genres for Route 94: []
#
# Processing track 671/1896
# Found genres for Kanye West: ['chicago rap', 'hip hop', 'rap']
#
# Processing track 1435/1896
# Found genres for Gotye: ['australian pop']
#
# Processing track 200/1896
# Found genres for Reckol: ['turkce drill', 'turkish hip hop']
#
# Processing track 646/1896
# Found genres for Hande Yener: ['turkish pop']
#
# Processing track 317/1896
# Found genres for ZHU: ['edm', 'electro house']
#
# Processing track 624/1896
# Found genres for Flo Dosh: []
#
# Processing track 495/1896
# Found genres for Barış Manço: ['anadolu rock', 'turkish instrumental', 'turkish psych', 'turkish rock']
#
# Processing track 1527/1896
# Found genres for The Blaze: ['new french touch']
#
# Processing track 1059/1896
# Found genres for Adam Port: ['melodic house']
#
# Processing track 134/1896
# Found genres for Ozan Çolakoğlu: ['turkish pop']
#
# Processing track 463/1896
# Found genres for MIIA: ['norwegian pop']
#
# Processing track 992/1896
# Found genres for Zeynep Bastık: ['turkish pop']
#
# Processing track 1574/1896
# Found genres for NTO: ['deep euro house', 'minimal melodic techno', 'new french touch']
#
# Processing track 843/1896
# Found genres for Yalın: ['turkish pop']
#
# Processing track 1514/1896
# Found genres for The Weeknd: ['canadian contemporary r&b', 'canadian pop', 'pop']
#
# Processing track 618/1896
# Found genres for ZHU: ['edm', 'electro house']
#
# Processing track 194/1896
# Found genres for Ceylan Ertem: ['turkish alt pop', 'turkish pop', 'turkish rock', 'turkish singer-songwriter']
#
# Processing track 1847/1896
# Found genres for Travis Scott: ['rap', 'slap house']
#
# Processing track 492/1896
# Found genres for XXXTENTACION: ['emo rap', 'miami hip hop', 'rap']
#
# Processing track 555/1896
# Found genres for Gala: ['eurodance', 'italo dance']
#
# Processing track 511/1896
# Found genres for RAFFA GUIDO: []
#
# Processing track 427/1896
# Found genres for cakal: ['turkce drill']
#
# Processing track 304/1896
# Found genres for Drake: ['canadian hip hop', 'canadian pop', 'hip hop', 'pop rap', 'rap']
#
# Processing track 790/1896
# Found genres for Ati242: ['turkish hip hop']
#
# Processing track 466/1896
# Found genres for Jeff Redd: ['new school turkce rap']
#
# Processing track 1701/1896
# Found genres for Nu: ['organic electronic']
#
# Processing track 1237/1896
# Found genres for SR: ['uk drill']
#
# Processing track 1156/1896
# Found genres for ZHU: ['edm', 'electro house']
#
# Processing track 1543/1896
# Found genres for Yalın: ['turkish pop']
#
# Processing track 13/1896
# Found genres for Ati242: ['turkish hip hop']
#
# Processing track 1771/1896
# Found genres for Yalın: ['turkish pop']
#
# Processing track 1349/1896
# Found genres for Hayzei: []
#
# Processing track 1047/1896
# Found genres for XXXTENTACION: ['emo rap', 'miami hip hop', 'rap']
#
# Processing track 1068/1896
# Found genres for ZHU: ['edm', 'electro house']
#
# Processing track 1439/1896
# Found genres for Hayden James: ['aussietronica', 'gauze pop', 'house']
#
# Processing track 1565/1896
# Found genres for James Mac: ['melodic house']
#
# Processing track 701/1896
# Found genres for Mahalo: []
#
# Processing track 500/1896
# Found genres for ZHU: ['edm', 'electro house']
#
# Processing track 1000/1896
# Found genres for Manu Chao: ['latin alternative', 'world']
#
# Processing track 1295/1896
# Found genres for Regard: ['pop dance', 'pop edm', 'slap house', 'uk dance']
#
# Processing track 80/1896
# Found genres for Cults: ['experimental pop', 'indie surf', 'pov: indie']
#
# Processing track 682/1896
# Found genres for Yalın: ['turkish pop']
#
# Processing track 394/1896
# Found genres for Fred again..: ['edm', 'house', 'stutter house']
#
# Processing track 1055/1896
# Found genres for Swedish House Mafia: ['edm', 'pop dance', 'progressive electro house']
#
# Processing track 1219/1896
# Found genres for TommyMuzzic: ['sped up']
#
# Processing track 1308/1896
# Found genres for Adele: ['british soul', 'pop', 'pop soul', 'uk pop']
#
# Processing track 409/1896
# Found genres for Kanye West: ['chicago rap', 'hip hop', 'rap']
#
# Processing track 953/1896
# Found genres for UZI: ['turkish hip hop', 'turkish trap']
#
# Processing track 1385/1896
# Found genres for Eftalya Yağcı: ['turkish pop']
#
# Processing track 1648/1896
# Found genres for NOIT: []
#
# Processing track 1212/1896
# Found genres for HUGEL: ['deep house']
#
# Processing track 102/1896
# Found genres for Tarkan: ['turkish pop']
#
# Processing track 1656/1896
# Found genres for Daft Punk: ['electro', 'filter house', 'rock']
#
# Processing track 273/1896
# Found genres for Travis Scott: ['rap', 'slap house']
#
# Processing track 583/1896
# Found genres for Mustafa Sandal: ['turkish pop']
#
# Processing track 925/1896
# Found genres for OTP: ['melodic drill']
#
# Processing track 170/1896
# Found genres for Ajda Pekkan: ['turkish pop', 'turkish psych']
#
# Processing track 1550/1896
# Found genres for hitcon5: []
#
# Processing track 1367/1896
# Found genres for Bengü: ['turkish pop']
#
# Processing track 1738/1896
# Found genres for Hande Yener: ['turkish pop']
#
# Processing track 1651/1896
# Found genres for Hzino: []
#
# Processing track 708/1896
# Found genres for INNA: ['dance pop', 'romanian house', 'romanian pop']
#
# Processing track 866/1896
# Found genres for Semicenk: ['turkish pop']
#
# Processing track 1038/1896
# Found genres for The Drums: ['brooklyn indie', 'indie surf']
#
# Processing track 1017/1896
# Found genres for Baby Gang: ['trap italiana']
#
# Processing track 122/1896
# Found genres for ZHU: ['edm', 'electro house']
#
# Processing track 219/1896
# Found genres for Yaşar: ['turkish pop']
#
# Processing track 74/1896
# Found genres for Ezhel: ['turkish hip hop', 'turkish trap']
#
# Processing track 138/1896
# Found genres for cakal: ['turkce drill']
#
# Processing track 1382/1896
# Found genres for Tarkan: ['turkish pop']
#
# Processing track 158/1896
# Found genres for INNA: ['dance pop', 'romanian house', 'romanian pop']
#
# Processing track 100/1896
# Found genres for Cigarettes After Sex: ['ambient pop', 'dream pop', 'el paso indie', 'shoegaze']
#
# Processing track 933/1896
# Found genres for FiloChill: ['slowed and reverb']
#
# Processing track 1043/1896
# Found genres for Makar: ['belgian hip hop']
#
# Processing track 380/1896
# Found genres for Steve Lacy: ['afrofuturism']
#
# Processing track 635/1896
# Found genres for Patron: ['turkish hip hop', 'turkish trap']
#
# Processing track 399/1896
# Found genres for Ezhel: ['turkish hip hop', 'turkish trap']
#
# Processing track 700/1896
# Found genres for Athena: ['turkish pop', 'turkish punk', 'turkish rock']
#
# Processing track 1672/1896
# Found genres for ZHU: ['edm', 'electro house']
#
# Processing track 1437/1896
# Found genres for Adele: ['british soul', 'pop', 'pop soul', 'uk pop']
#
# Processing track 1642/1896
# Found genres for 24kGoldn: ['cali rap', 'pop rap']
#
# Processing track 1392/1896
# Found genres for SativaMusic: []
#
# Processing track 1541/1896
# Found genres for Motive: ['turkish hip hop', 'turkish trap']
#
# Processing track 410/1896
# Found genres for Ati242: ['turkish hip hop']
#
# Processing track 1284/1896
# Found genres for ANOTR: ['dutch tech house']
#
# Processing track 1328/1896
# Found genres for UZI: ['turkish hip hop', 'turkish trap']
#
# Processing track 1451/1896
# Found genres for Coldplay: ['permanent wave', 'pop']
#
# Processing track 902/1896
# Found genres for Juice WRLD: ['chicago rap', 'melodic rap', 'rap']
#
# Processing track 524/1896
# Found genres for Bsav GP: []
#
# Processing track 1719/1896
# Found genres for ZHU: ['edm', 'electro house']
#
# Processing track 1201/1896
# Found genres for ZHU: ['edm', 'electro house']
#
# Processing track 422/1896
# Found genres for James Hype: ['deep groove house', 'house', 'pop dance', 'uk dance']
#
# Processing track 1581/1896
# Found genres for Vincemp3: []
#
# Processing track 5/1896
# Found genres for Lil Zey: ['turkce kadin rap', 'turkish hip hop', 'turkish trap']
#
# Processing track 482/1896
# Found genres for Kıraç: ['anadolu rock', 'turkish pop', 'turkish rock']
#
# Processing track 1615/1896
# Found genres for Rod Wave: ['florida rap']
#
# Processing track 1063/1896
# Found genres for Sophie Ellis-Bextor: ['dance pop', 'europop', 'new wave pop']
#
# Processing track 775/1896
# Found genres for INNA: ['dance pop', 'romanian house', 'romanian pop']
#
# Processing track 67/1896
# Found genres for Erdem Kınay: ['turkish pop']
#
# Processing track 1453/1896
# Found genres for Beach Bunny: ['bubblegrunge', 'chicago indie', 'indie pop', 'pov: indie']
#
# Processing track 329/1896
# No results found for Collar of Truth by Fiuge
#
# Processing track 776/1896
# Found genres for Daft Punk: ['electro', 'filter house', 'rock']
#
# Processing track 1438/1896
# Found genres for Eyedress: ['noise pop', 'pov: indie']
#
# Processing track 615/1896
# Found genres for Eminem: ['detroit hip hop', 'hip hop', 'rap']
#
# Processing track 1764/1896
# Found genres for Quarterhead: ['tech house']
#
# Processing track 954/1896
# Found genres for 6ix9ine: ['emo rap']
#
# Processing track 1122/1896
# Found genres for The Rare Occasions: ['la indie']
#
# Processing track 597/1896
# Found genres for Kibariye: ['arabesk', 'turkish pop']
#
# Processing track 14/1896
# Found genres for Dominic Fike: ['alternative pop rock', 'pov: indie']
#
# Processing track 135/1896
# Found genres for Şam: ['turkish hip hop', 'turkish trap']
#
# Processing track 1511/1896
# Found genres for Kendrick Lamar: ['conscious hip hop', 'hip hop', 'rap', 'west coast rap']
#
# Processing track 198/1896
# Found genres for Hande Yener: ['turkish pop']
#
# Processing track 27/1896
# Found genres for Lil Zey: ['turkce kadin rap', 'turkish hip hop', 'turkish trap']
#
# Processing track 1649/1896
# Found genres for Daft Punk: ['electro', 'filter house', 'rock']
#
# Processing track 77/1896
# Found genres for Benzz: []
#
# Processing track 976/1896
# Found genres for UZI: ['turkish hip hop', 'turkish trap']
#
# Processing track 488/1896
# Found genres for Lil Zey: ['turkce kadin rap', 'turkish hip hop', 'turkish trap']
#
# Processing track 1871/1896
# Found genres for cakal: ['turkce drill']
#
# Processing track 444/1896
# Found genres for The Chainsmokers: ['pop']
#
# Processing track 1874/1896
# Found genres for Era7capone: ['new school turkce rap']
#
# Processing track 1009/1896
# Found genres for THE ANXIETY: ['modern alternative pop']
#
# Processing track 1222/1896
# Found genres for Lil Zey: ['turkce kadin rap', 'turkish hip hop', 'turkish trap']
#
# Processing track 278/1896
# Found genres for INNA: ['dance pop', 'romanian house', 'romanian pop']
#
# Processing track 1140/1896
# Found genres for The Weeknd: ['canadian contemporary r&b', 'canadian pop', 'pop']
#
# Processing track 1755/1896
# Found genres for Lil Zey: ['turkce kadin rap', 'turkish hip hop', 'turkish trap']
#
# Processing track 1002/1896
# Found genres for Manu Chao: ['latin alternative', 'world']
#
# Processing track 931/1896
# Found genres for Daft Punk: ['electro', 'filter house', 'rock']
#
# Processing track 1346/1896
# Found genres for Atiye: ['turkish pop']
#
# Processing track 859/1896
# Found genres for Bengü: ['turkish pop']
#
# Processing track 662/1896
# Found genres for Aydın Kurtoğlu: ['turkish pop']
#
# Processing track 705/1896
# Found genres for INNA: ['dance pop', 'romanian house', 'romanian pop']
#
# Processing track 1470/1896
# Found genres for ZHU: ['edm', 'electro house']
#
# Processing track 188/1896
# Found genres for Ayten Alpman: ['classic turkish pop', 'turkish jazz', 'turkish modern jazz']
#
# Processing track 217/1896
# Found genres for Genç Fenerbahçeliler: []
#
# Processing track 1804/1896
# Found genres for Travis Scott: ['rap', 'slap house']
#
# Processing track 55/1896
# Found genres for Don Toliver: ['rap']
#
# Processing track 1549/1896
# Found genres for Ayten Alpman: ['classic turkish pop', 'turkish jazz', 'turkish modern jazz']
#
# Processing track 1171/1896
# Found genres for Grits: ['christian hip hop']
#
# Processing track 401/1896
# Found genres for ZHU: ['edm', 'electro house']
#
# Processing track 1093/1896
# Found genres for Current Joys: ['lo-fi indie', 'pov: indie']
#
# Processing track 967/1896
# Found genres for DJ Dart: []
#
# Processing track 1081/1896
# Found genres for Hidra: ['turkish hip hop', 'turkish trap']
#
# Processing track 1593/1896
# Found genres for Metro Boomin: ['rap']
#
# Processing track 1179/1896
# Found genres for Calvin Harris: ['dance pop', 'edm', 'electro house', 'house', 'pop', 'progressive house', 'uk dance']
#
# Processing track 1683/1896
# Found genres for Pop Smoke: ['brooklyn drill', 'hip hop', 'rap']
#
# Processing track 1640/1896
# Found genres for Göksel: ['turkce slow sarkilar', 'turkish pop']
#
# Processing track 1323/1896
# Found genres for Troye Sivan: ['australian pop', 'pop', 'viral pop']
#
# Processing track 185/1896
# Found genres for Serdar Ortaç: ['turkish pop']
#
# Processing track 1662/1896
# Found genres for Ichiss: []
#
# Processing track 469/1896
# Found genres for Ferhat Göçer: ['turkish pop']
#
# Processing track 1873/1896
# Found genres for Lvbel C5: ['turkce drill', 'turkish trap']
#
# Processing track 574/1896
# Found genres for Serdar Ortaç: ['turkish pop']
#
# Processing track 588/1896
# Found genres for Murat Boz: ['turkish pop']
#
# Processing track 837/1896
# Found genres for Sedef Sebüktekin: ['turkish alt pop', 'turkish rock']
#
# Processing track 234/1896
# Found genres for DJ Anilson: []
#
# Processing track 1441/1896
# Found genres for Nilüfer: ['turkish pop']
#
# Processing track 1503/1896
# Found genres for Güneş: ['turkce kadin rap']
#
# Processing track 644/1896
# Found genres for Büyük Ev Ablukada: ['turkish alternative rock', 'turkish rock']
#
# Processing track 1690/1896
# Found genres for SR: ['uk drill']
#
# Processing track 934/1896
# Found genres for Gesaffelstein: ['dark clubbing']
#
# Processing track 49/1896
# Found genres for Tarkan: ['turkish pop']
#
# Processing track 363/1896
# Found genres for Lil Zey: ['turkce kadin rap', 'turkish hip hop', 'turkish trap']
#
# Processing track 1512/1896
# Found genres for Sofi Tukker: ['edm']
#
# Processing track 861/1896
# Found genres for Yaşar: ['turkish pop']
#
# Processing track 1872/1896
# Found genres for Simge: ['deep turkish pop', 'persian pop', 'turkish pop']
#
# Processing track 797/1896
# Found genres for Benzz: []
#
# Processing track 309/1896
# Found genres for TV Girl: ['pov: indie']
#
# Processing track 943/1896
# Found genres for ZHU: ['edm', 'electro house']
#
# Processing track 338/1896
# Found genres for Central Cee: ['melodic drill', 'r&drill']
#
# Processing track 523/1896
# Found genres for Bsav GP: []
#
# Processing track 1394/1896
# Found genres for 1nonly: ['aesthetic rap']
#
# Processing track 269/1896
# Found genres for Güneş: ['turkce kadin rap']
#
# Processing track 1752/1896
# Found genres for Serdar Ortaç: ['turkish pop']
#
# Processing track 1568/1896
# Found genres for The Weeknd: ['canadian contemporary r&b', 'canadian pop', 'pop']
#
# Processing track 54/1896
# Found genres for The Weeknd: ['canadian contemporary r&b', 'canadian pop', 'pop']
#
# Processing track 266/1896
# Found genres for ZHU: ['edm', 'electro house']
#
# Processing track 1735/1896
# Found genres for Simge: ['deep turkish pop', 'persian pop', 'turkish pop']
#
# Processing track 212/1896
# Found genres for Yalın: ['turkish pop']
#
# Processing track 684/1896
# Found genres for Lil Zey: ['turkce kadin rap', 'turkish hip hop', 'turkish trap']
#
# Processing track 323/1896
# Found genres for INNA: ['dance pop', 'romanian house', 'romanian pop']
#
# Processing track 1890/1896
# Found genres for Misha Xramovi: ['georgian hip hop']
#
# Processing track 560/1896
# Found genres for Chase Atlantic: ['alternative r&b']
#
# Processing track 1877/1896
# Found genres for Gülşen: []
#
# Processing track 64/1896
# Found genres for Sertab Erener: ['turkish jazz', 'turkish pop', 'turkish singer-songwriter']
#
# Processing track 29/1896
# Found genres for Kleo: []
#
# Processing track 713/1896
# Found genres for The Weeknd: ['canadian contemporary r&b', 'canadian pop', 'pop']
#
# Processing track 1006/1896
# Found genres for Buray: ['turkish deep house', 'turkish pop']
#
# Processing track 191/1896
# Found genres for Hande Yener: ['turkish pop']
#
# Processing track 69/1896
# Found genres for Juice WRLD: ['chicago rap', 'melodic rap', 'rap']
#
# Processing track 965/1896
# Found genres for Elley Duhé: ['alt z']
#
# Processing track 1158/1896
# Found genres for Daft Punk: ['electro', 'filter house', 'rock']
#
# Processing track 564/1896
# Found genres for JACKBOYS: ['pop rap']
#
# Processing track 773/1896
# Found genres for Giggs: ['grime', 'london rap', 'uk hip hop']
#
# Processing track 507/1896
# Found genres for Lil Peep: ['cloud rap', 'emo rap', 'lgbtq+ hip hop']
#
# Processing track 1646/1896
# Found genres for Kenan Doğulu: ['turkish pop']
#
# Processing track 1445/1896
# Found genres for Hande Yener: ['turkish pop']
#
# Processing track 937/1896
# Found genres for INNA: ['dance pop', 'romanian house', 'romanian pop']
#
# Processing track 1304/1896
# Found genres for cakal: ['turkce drill']
#
# Processing track 93/1896
# Found genres for Maroon 5: ['pop']
#
# Processing track 1269/1896
# Found genres for Vegedream: ['french hip hop', 'pop urbaine', 'r&b francais']
#
# Processing track 1753/1896
# Found genres for Son-us: []
#
# Processing track 951/1896
# Found genres for Zara Larsson: ['pop', 'scandipop', 'swedish electropop', 'swedish pop']
#
# Processing track 26/1896
# Found genres for Russ Millions: ['melodic drill', 'uk drill']
#
# Processing track 1884/1896
# Found genres for Tarkan: ['turkish pop']
#
# Processing track 159/1896
# Found genres for Inner Circle: ['reggae', 'reggae fusion']
#
# Processing track 110/1896
# Found genres for Daft Punk: ['electro', 'filter house', 'rock']
#
# Processing track 142/1896
# Found genres for Göksel: ['turkce slow sarkilar', 'turkish pop']
#
# Processing track 1577/1896
# Found genres for ZHU: ['edm', 'electro house']
#
# Processing track 343/1896
# Found genres for Ajda Pekkan: ['turkish pop', 'turkish psych']
#
# Processing track 1500/1896
# Found genres for Eminem: ['detroit hip hop', 'hip hop', 'rap']
#
# Processing track 1363/1896
# Found genres for ZHU: ['edm', 'electro house']
#
# Processing track 1243/1896
# Found genres for Lilly Wood and The Prick: ['french indie pop', 'french rock']
#
# Processing track 1456/1896
# Found genres for Lil Peep: ['cloud rap', 'emo rap', 'lgbtq+ hip hop']
#
# Processing track 1854/1896
# Found genres for Tate McRae: ['pop']
#
# Processing track 625/1896
# Found genres for ZHU: ['edm', 'electro house']
#
# Processing track 1249/1896
# Found genres for Daft Punk: ['electro', 'filter house', 'rock']
#
# Processing track 1586/1896
# Found genres for La Caution: ['old school rap francais']
#
# Processing track 402/1896
# Found genres for Morris: ['romanian house']
#
# Processing track 1080/1896
# Found genres for Lvbel C5: ['turkce drill', 'turkish trap']
#
# Processing track 391/1896
# Found genres for INNA: ['dance pop', 'romanian house', 'romanian pop']
#
# Processing track 1526/1896
# Found genres for Lvbel C5: ['turkce drill', 'turkish trap']
#
# Processing track 1516/1896
# Found genres for Norm Ender: ['turkish hip hop', 'turkish trap']
#
# Processing track 1524/1896
# Found genres for MLQ 2N: []
#
# Processing track 262/1896
# Found genres for La Roux: ['alternative dance', 'electropop', 'indietronica', 'neo-synthpop']
#
# Processing track 928/1896
# Found genres for Joy Again: ['pov: indie']
#
# Processing track 1348/1896
# Found genres for Morphia: ['huzunlu sarkilar']
#
# Processing track 460/1896
# Found genres for Güneş: ['turkce kadin rap']
#
# Processing track 133/1896
# Found genres for Yalın: ['turkish pop']
#
# Processing track 1303/1896
# Found genres for Artz: ['turkish hip hop', 'turkish trap']
#
# Processing track 549/1896
# Found genres for HUGEL: ['deep house']
#
# Processing track 1276/1896
# Found genres for Paradise Delay: []
#
# Processing track 658/1896
# Found genres for Serdar Ortaç: ['turkish pop']
#
# Processing track 874/1896
# Found genres for Toto Cutugno: ['classic italian pop']
#
# Processing track 346/1896
# Found genres for OneRepublic: ['piano rock', 'pop']
#
# Processing track 1601/1896
# Found genres for Stromae: ['belgian pop', 'g-house']
#
# Processing track 373/1896
# Found genres for cakal: ['turkce drill']
#
# Processing track 1067/1896
# Found genres for Rick Groove: []
#
# Processing track 94/1896
# Found genres for Ayla Dikmen: ['classic turkish pop']
#
# Processing track 1814/1896
# Found genres for Izzamuzzic: ['kazakh pop', 'russian electronic']
#
# Processing track 1575/1896
# Found genres for Tiësto: ['big room', 'brostep', 'dutch edm', 'edm', 'house', 'pop dance', 'progressive electro house', 'slap house', 'trance']
#
# Processing track 1090/1896
# Found genres for Drenchill: ['pop edm']
#
# Processing track 1079/1896
# Found genres for Güneş: ['turkce drill', 'turkish trap']
#
# Processing track 1466/1896
# Found genres for Dr. Dre: ['g funk', 'gangster rap', 'hip hop', 'rap', 'west coast rap']
#
# Processing track 1750/1896
# Found genres for cakal: ['turkce drill']
#
# Processing track 550/1896
# Found genres for Stromae: ['belgian pop', 'g-house']
#
# Processing track 554/1896
# Found genres for Bondex: []
#
# Processing track 1115/1896
# Found genres for Young Community: []
#
# Processing track 691/1896
# Found genres for Kayra: ['turkish hip hop']
#
# Processing track 1636/1896
# Found genres for French Montana: ['hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap']
#
# Processing track 628/1896
# Found genres for Demet Akalın: ['turkish pop']
#
# Processing track 177/1896
# Found genres for Ezhel: ['turkish hip hop', 'turkish trap']
#
# Processing track 433/1896
# Found genres for Farazi: ['turkish hip hop']
#
# Processing track 166/1896
# Found genres for Göksel: ['turkce slow sarkilar', 'turkish pop']
#
# Processing track 1832/1896
# Found genres for Lvbel C5: ['turkce drill', 'turkish trap']
#
# Processing track 1457/1896
# Found genres for The Weeknd: ['canadian contemporary r&b', 'canadian pop', 'pop']
#
# Processing track 903/1896
# Found genres for DJ Snake: ['dance pop', 'edm', 'electronic trap', 'pop', 'pop dance']
#
# Processing track 1667/1896
# Found genres for Kwabs: ['gauze pop']
#
# Processing track 1290/1896
# Found genres for Joachim Pastor: ['deep euro house', 'french tech house', 'minimal melodic techno', 'new french touch']
#
# Processing track 513/1896
# Found genres for Bazzi: ['pop']
#
# Processing track 556/1896
# Found genres for Drenchill: ['pop edm']
#
# Processing track 677/1896
# Found genres for Merve Özbey: ['turkish pop']
#
# Processing track 600/1896
# Found genres for Daft Punk: ['electro', 'filter house', 'rock']
#
# Processing track 1844/1896
# Found genres for Post Malone: ['dfw rap', 'melodic rap', 'pop', 'rap']
#
# Processing track 1281/1896
# Found genres for Russ Millions: ['melodic drill', 'uk drill']
#
# Processing track 1729/1896
# Found genres for EDIS: ['turkish pop']
#
# Processing track 1338/1896
# Found genres for Bengü: ['turkish pop']
#
# Processing track 1289/1896
# Found genres for XXXTENTACION: ['emo rap', 'miami hip hop', 'rap']
#
# Processing track 1421/1896
# Found genres for Sade: ['british soul', 'sophisti-pop']
#
# Processing track 907/1896
# Found genres for ZHU: ['edm', 'electro house']
#
# Processing track 218/1896
# Found genres for Gülşen: ['turkish pop']
#
# Processing track 1239/1896
# Found genres for cassö: ['hypertechno', 'pop dance']
#
# Processing track 1465/1896
# Found genres for Edward Maya: ['romanian house', 'romanian pop']
#
# Processing track 1001/1896
# Found genres for Manu Chao: ['latin alternative', 'world']
#
# Processing track 1230/1896
# Found genres for Şehinşah: ['turkish hip hop', 'turkish trap']
#
# Processing track 780/1896
# Found genres for Chase Atlantic: ['alternative r&b']
#
# Processing track 1557/1896
# Found genres for Sean Paul: ['dance pop', 'dancehall', 'pop', 'pop rap']
#
# Processing track 1144/1896
# Found genres for Lil Zey: ['turkce kadin rap', 'turkish hip hop', 'turkish trap']
#
# Processing track 741/1896
# Found genres for Cameron Grey: []
#
# Processing track 1517/1896
# Found genres for Gülben Ergen: ['arabesk', 'turkish pop']
#
# Processing track 955/1896
# Found genres for Motive: ['turkish hip hop', 'turkish trap']
#
# Processing track 1862/1896
# Found genres for Lil Zey: ['turkce kadin rap', 'turkish hip hop', 'turkish trap']
#
# Processing track 1825/1896
# Found genres for berlioz: ['jazz house']
#
# Processing track 1172/1896
# Found genres for SZA: ['pop', 'r&b', 'rap']
#
# Processing track 1867/1896
# Found genres for Cámille: []
#
# Processing track 927/1896
# Found genres for Carinth: []
#
# Processing track 1805/1896
# Found genres for Tate McRae: ['pop']
#
# Processing track 527/1896
# Found genres for Slowed Remix DJ: []
#
# Processing track 1414/1896
# Found genres for SamRecks: []
#
# Processing track 115/1896
# Found genres for Deeter K: []
#
# Processing track 715/1896
# Found genres for Calvin Harris: ['dance pop', 'edm', 'electro house', 'house', 'pop', 'progressive house', 'uk dance']
#
# Processing track 825/1896
# Found genres for Bengü: ['turkish pop']
#
# Processing track 884/1896
# Found genres for Naughty Boy: ['uk contemporary r&b']
#
# Processing track 1520/1896
# Found genres for Hadise: ['turkish deep house', 'turkish pop']
#
# Processing track 676/1896
# Found genres for Erdem Kınay: ['turkish pop']
#
# Processing track 214/1896
# Found genres for Hakan Peker: ['turkish pop']
#
# Processing track 995/1896
# Found genres for Lil Zey: ['turkce kadin rap', 'turkish hip hop', 'turkish trap']
#
# Processing track 270/1896
# Found genres for Anıl Piyancı: ['turkce drill', 'turkish hip hop', 'turkish trap']
#
# Processing track 437/1896
# Found genres for Central Cee: ['melodic drill', 'r&drill']
#
# Processing track 405/1896
# Found genres for Pink Beaches: []
#
# Processing track 1274/1896
# Found genres for ZHU: ['edm', 'electro house']
#
# Processing track 60/1896
# Found genres for Felix Jaehn: ['edm', 'german dance', 'pop dance', 'tropical house', 'uk dance']
#
# Processing track 991/1896
# Found genres for Lil Zey: ['turkce kadin rap', 'turkish hip hop', 'turkish trap']
#
# Processing track 768/1896
# Found genres for INNA: ['dance pop', 'romanian house', 'romanian pop']
#
# Processing track 1446/1896
# Found genres for Hande Yener: ['turkish pop']
#
# Processing track 76/1896
# Found genres for West & Zander: []
#
# Processing track 693/1896
# Found genres for G-Eazy: ['indie pop rap', 'oakland hip hop', 'pop rap', 'rap']
#
# Processing track 1533/1896
# Found genres for Sinan Akçıl: ['turkish pop']
#
# Processing track 371/1896
# Found genres for Batuflex: ['turkish hip hop', 'turkish trap']
#
# Processing track 935/1896
# Found genres for LP: ['la pop', "women's music"]
#
# Processing track 1775/1896
# Found genres for Lil Zey: ['turkce kadin rap', 'turkish hip hop', 'turkish trap']
#
# Processing track 1199/1896
# Found genres for Stromae: ['belgian pop', 'g-house']
#
# Processing track 1298/1896
# Found genres for Bending Lights: []
#
# Processing track 1227/1896
# Found genres for Lil Zey: ['turkce kadin rap', 'turkish hip hop', 'turkish trap']
#
# Processing track 983/1896
# Found genres for Phoenix Rouge: []
#
# Processing track 653/1896
# Found genres for Daft Punk: ['electro', 'filter house', 'rock']
#
# Processing track 50/1896
# Found genres for Daft Punk: ['electro', 'filter house', 'rock']
#
# Processing track 300/1896
# Found genres for Shakira: ['colombian pop', 'dance pop', 'latin pop', 'pop']
#
# Processing track 1251/1896
# Found genres for cakal: ['turkce drill']
#
# Processing track 880/1896
# Found genres for chipbagov: ['gym phonk']
#
# Processing track 366/1896
# Found genres for AKDO: []
#
# Processing track 1736/1896
# Found genres for Derya Uluğ: ['turkish pop']
#
# Processing track 8/1896
# Found genres for Stefflon Don: ['dancehall', 'dancehall queen', 'uk dancehall', 'uk hip hop']
#
# Processing track 813/1896
# Found genres for Lil Uzi Vert: ['hip hop', 'melodic rap', 'philly rap', 'rage rap', 'rap', 'trap']
#
# Processing track 528/1896
# Found genres for James Hype: ['deep groove house', 'house', 'pop dance', 'uk dance']
#
# Processing track 1200/1896
# Found genres for Eden Shalev: []
#
# Processing track 1870/1896
# Found genres for KÖK$VL: ['turkce trap metal', 'turkish hip hop', 'turkish trap']
#
# Processing track 1433/1896
# Found genres for Kit Genova: []
#
# Processing track 40/1896
# Found genres for M Lisa: []
#
# Processing track 552/1896
# Found genres for Surf Curse: ['dreamo', 'indie surf', 'pov: indie', 'surf punk', 'vegas indie']
#
# Processing track 1705/1896
# Found genres for Arctic Monkeys: ['garage rock', 'modern rock', 'permanent wave', 'rock', 'sheffield indie']
#
# Processing track 753/1896
# Found genres for Monic: []
#
# Processing track 1147/1896
# Found genres for NOAH: ['german hip hop']
#
# Processing track 367/1896
# Found genres for Daft Punk: ['electro', 'filter house', 'rock']
#
# Processing track 1236/1896
# Found genres for Serdar Ortaç: ['turkish pop']
#
# Processing track 1134/1896
# Found genres for Central Cee: ['melodic drill', 'r&drill']
#
# Processing track 231/1896
# Found genres for Penga Scain: []
#
# Processing track 1004/1896
# Found genres for G-Eazy: ['indie pop rap', 'oakland hip hop', 'pop rap', 'rap']
#
# Processing track 400/1896
# Found genres for Demet Akalın: ['turkish pop']
#
# Processing track 675/1896
# Found genres for 9Fivey: []
#
# Processing track 1208/1896
# Found genres for The Weeknd: ['canadian contemporary r&b', 'canadian pop', 'pop']
#
# Processing track 1105/1896
# Found genres for Dr. Alban: ['eurodance', 'europop', 'hip house']
#
# Processing track 1042/1896
# Found genres for DJ F3ARL3SS: ['phonk brasileiro']
#
# Processing track 118/1896
# No results found for Ateşi Yak by ilkekw
#
# Processing track 283/1896
# Found genres for mor ve ötesi: ['turkish alternative', 'turkish alternative rock', 'turkish rock']
#
# Processing track 1259/1896
# Found genres for Motive: ['turkish hip hop', 'turkish trap']
#
# Processing track 752/1896
# Found genres for Thoinas: []
#
# Processing track 1253/1896
# Found genres for ZHU: ['edm', 'electro house']
#
# Processing track 1641/1896
# Found genres for Ozan Doğulu: ['karadeniz pop', 'turkish pop']
#
# Processing track 732/1896
# Found genres for Katy Perry: ['pop']
#
# Processing track 1707/1896
# Found genres for The Weeknd: ['canadian contemporary r&b', 'canadian pop', 'pop']
#
# Processing track 1759/1896
# Found genres for NVOY: ['deep groove house', 'house']
#
# Processing track 1332/1896
# Found genres for Jasise: []
#
# Processing track 295/1896
# Found genres for Ebru Gündeş: ['arabesk', 'turkish folk', 'turkish pop']
#
# Processing track 582/1896
# Found genres for Ezhel: ['turkish hip hop', 'turkish trap']
#
# Processing track 167/1896
# Found genres for Gueves: []
#
# Processing track 898/1896
# Found genres for Comfykids: []
#
# Processing track 1166/1896
# Found genres for Mads Nielsen Stolt: []
#
# Processing track 698/1896
# Found genres for D-Phunk420: []
#
# Processing track 807/1896
# Found genres for Fred again..: ['edm', 'house', 'stutter house']
#
# Processing track 744/1896
# Found genres for Lewis Hanton: ['sped up']
#
# Processing track 1384/1896
# Found genres for Sıla: ['turkish pop']
#
# Processing track 429/1896
# Found genres for ATE: ['turkish hip hop']
#
# Processing track 456/1896
# Found genres for Vossberg: ['belgian electronic']
#
# Processing track 1280/1896
# Found genres for Russ Millions: ['melodic drill', 'uk drill']
#
# Processing track 1850/1896
# Found genres for Yung Kyoto: ['aesthetic rap']
#
# Processing track 546/1896
# Found genres for Pop Smoke: ['brooklyn drill', 'hip hop', 'rap']
#
# Processing track 439/1896
# Found genres for Camisade: []
#
# Processing track 486/1896
# Found genres for Tuhan: ['turkish trap']
#
# Processing track 78/1896
# Found genres for Stromae: ['belgian pop', 'g-house']
#
# Processing track 1012/1896
# Found genres for Duke Dumont: ['edm', 'house', 'pop dance', 'progressive house', 'uk dance']
#
# Processing track 867/1896
# Found genres for Ezhel: ['turkish hip hop', 'turkish trap']
#
# Processing track 755/1896
# Found genres for Gibran Alcocer: ['ambient lo-fi']
#
# Processing track 428/1896
# Found genres for cakal: ['turkce drill']
#
# Processing track 342/1896
# Found genres for Chase Atlantic: ['alternative r&b']
#
# Processing track 1039/1896
# Found genres for ZHU: ['edm', 'electro house']
#
# Processing track 592/1896
# Found genres for Soul to Speak: ['beach house']
#
# Processing track 56/1896
# Found genres for Flamentone: []
#
# Processing track 1211/1896
# Found genres for Ben Travel: []
#
# Processing track 1479/1896
# Found genres for Carla's Dreams: ['moldovan pop', 'romanian pop']
#
# Processing track 919/1896
# Found genres for Central Cee: ['melodic drill', 'r&drill']
#
# Processing track 365/1896
# Found genres for Emin Nilsen: []
#
# Processing track 1467/1896
# Found genres for Labrinth: ['indie poptimism', 'pop']
#
# Processing track 950/1896
# Found genres for Future: ['atl hip hop', 'hip hop', 'rap', 'southern hip hop', 'trap']
#
# Processing track 417/1896
# Found genres for Daft Punk: ['electro', 'filter house', 'rock']
#
# Processing track 1490/1896
# Found genres for Lana Del Rey: ['art pop', 'pop']
#
# Processing track 494/1896
# Found genres for André Aguado: []
#
# Processing track 1763/1896
# Found genres for PeachPuff: []
#
# Processing track 1209/1896
# Found genres for Midas the Jagaban: ['afroswing']
#
# Processing track 580/1896
# Found genres for FloyyMenor: ['reggaeton chileno']
#
# Processing track 351/1896
# Found genres for Lou Kil: []
#
# Processing track 431/1896
# Found genres for Arctic Monkeys: ['garage rock', 'modern rock', 'permanent wave', 'rock', 'sheffield indie']
#
# Processing track 224/1896
# Found genres for The Weeknd: ['canadian contemporary r&b', 'canadian pop', 'pop']
#
# Processing track 1257/1896
# Found genres for Demet Akalın: ['turkish pop']
#
# Processing track 714/1896
# Found genres for Emel Müftüoğlu: ['turkish pop']
#
# Processing track 690/1896
# Found genres for Coldplay: ['permanent wave', 'pop']
#
# Processing track 478/1896
# Found genres for Pop Smoke: ['brooklyn drill', 'hip hop', 'rap']
#
# Processing track 728/1896
# Found genres for Lykke Li: ['art pop', 'electropop', 'indietronica', 'neo-synthpop', 'swedish electropop', 'swedish indie pop', 'swedish pop']
#
# Processing track 1785/1896
# Found genres for Parker Son: []
#
# Processing track 996/1896
# Found genres for Şebnem Ferah: ['turkish pop', 'turkish rock']
#
# Processing track 743/1896
# Found genres for Gloria Gaynor: ['disco', 'soft rock']
#
# Processing track 641/1896
# Found genres for Lvbel C5: ['turkce drill', 'turkish trap']
#
# Processing track 1597/1896
# Found genres for Starioh: []
#
# Processing track 1546/1896
# Found genres for GRNY: []
#
# Processing track 704/1896
# Found genres for Daft Punk: ['electro', 'filter house', 'rock']
#
# Processing track 1130/1896
# Found genres for JACKBOYS: ['pop rap']
#
# Processing track 1815/1896
# Found genres for Goose Groovy: ['beach house']
#
# Processing track 1650/1896
# Found genres for KD Simon: []
#
# Processing track 958/1896
# Found genres for Elley Duhé: ['alt z']
#
# Processing track 631/1896
# Found genres for Kibariye: ['arabesk', 'turkish pop']
#
# Processing track 1370/1896
# Found genres for The Weeknd: ['canadian contemporary r&b', 'canadian pop', 'pop']
#
# Processing track 1774/1896
# Found genres for Güneş: ['turkce kadin rap']
#
# Processing track 1461/1896
# Found genres for ZHU: ['edm', 'electro house']
#
# Processing track 1798/1896
# Found genres for Isabel LaRosa: ['hyperpop', 'sped up']
#
# Processing track 1673/1896
# Found genres for T.H. Express: ['eurodance']
#
# Processing track 1487/1896
# Found genres for Vee Jay: []
#
# Processing track 804/1896
# Found genres for Mark Eliyahu: ['turkish instrumental']
#
# Processing track 1210/1896
# Found genres for Parra for Cuva: ['deep euro house', 'downtempo', 'new french touch']
#
# Processing track 1587/1896
# Found genres for The Weeknd: ['canadian contemporary r&b', 'canadian pop', 'pop']
#
# Processing track 1123/1896
# Found genres for ZHU: ['edm', 'electro house']
#
# Processing track 1548/1896
# Found genres for Peed Hus: []
#
# Processing track 1677/1896
# Found genres for Empire Of The Sun: ['australian dance', 'australian electropop', 'dance rock', 'indietronica', 'neo-synthpop']
#
# Processing track 1560/1896
# Found genres for ZHU: ['edm', 'electro house']
#
# Processing track 1175/1896
# Found genres for Chairten: []
#
# Processing track 1416/1896
# Found genres for ZHU: ['edm', 'electro house']
#
# Processing track 984/1896
# Found genres for NGHTMRE: ['brostep', 'edm', 'electro house', 'electronic trap']
#
# Processing track 1824/1896
# Found genres for sir bennett: []
#
# Processing track 12/1896
# Found genres for ALIZADE: ['zhenskiy rep']
#
# Processing track 598/1896
# Found genres for ABBA: ['europop', 'swedish pop']
#
# Processing track 1497/1896
# Found genres for ZHU: ['edm', 'electro house']
#
# Processing track 727/1896
# Found genres for Two Feet: ['indie poptimism', 'modern rock']
#
# Processing track 1823/1896
# Found genres for Lil Zey: ['turkce kadin rap', 'turkish hip hop', 'turkish trap']
#
# Processing track 39/1896
# Found genres for SICK LEGEND: ['gym hardstyle']
#
# Processing track 1800/1896
# Found genres for flooww: []
#
# Processing track 325/1896
# Found genres for ZHU: ['edm', 'electro house']
#
# Processing track 721/1896
# Found genres for Coldplay: ['permanent wave', 'pop']
#
# Processing track 612/1896
# Found genres for Ahzee: []
#
# Processing track 1314/1896
# Found genres for Young Bego: ['turkish trap']
#
# Processing track 1855/1896
# Found genres for Mikayl Blu: []
#
# Processing track 477/1896
# Found genres for ZHU: ['edm', 'electro house']
#
# Processing track 1411/1896
# Found genres for Beny Jr: ['drill espanol', 'urbano espanol']
#
# Processing track 839/1896
# Found genres for Saint Haux: []
#
# Processing track 316/1896
# Found genres for Closest Cloud: []
#
# Processing track 818/1896
# Found genres for Jordan Adetunji: ['irish hip hop']
#
# Processing track 1886/1896
# Found genres for Ezhel: ['turkish hip hop', 'turkish trap']
#
# Processing track 801/1896
# Found genres for Mustafa Sandal: ['turkish pop']
#
# Processing track 141/1896
# Found genres for Simge: ['deep turkish pop', 'persian pop', 'turkish pop']
#
# Processing track 605/1896
# Found genres for Pitbull: ['dance pop', 'miami hip hop', 'pop']
#
# Processing track 120/1896
# Found genres for Syrex: ['nightcore']
#
# Processing track 629/1896
# Found genres for Khontkar: ['turkish hip hop', 'turkish trap']
#
# Processing track 436/1896
# Found genres for Daft Punk: ['electro', 'filter house', 'rock']
#
# Processing track 223/1896
# Found genres for Hibiscus: []
#
# Processing track 1724/1896
# Found genres for Lvbel C5: ['turkce drill', 'turkish trap']
#
# Processing track 1162/1896
# Found genres for The Weeknd: ['canadian contemporary r&b', 'canadian pop', 'pop']
#
# Processing track 384/1896
# Found genres for Sonic: []
#
# Processing track 661/1896
# Found genres for Ezhel: ['turkish hip hop', 'turkish trap']
#
# Processing track 532/1896
# Found genres for Pitbull: ['dance pop', 'miami hip hop', 'pop']
#
# Processing track 1505/1896
# Found genres for The Neighbourhood: ['modern alternative rock', 'modern rock', 'pop']
#
# Processing track 1595/1896
# Found genres for Deeter K: []
#
# Processing track 1813/1896
# Found genres for Hello Papyrus: []
#
# Processing track 1287/1896
# Found genres for Aaryan Shah: ['dark r&b']
#
# Processing track 1864/1896
# Found genres for Lil Zey: ['turkce kadin rap', 'turkish hip hop', 'turkish trap']
#
# Processing track 1121/1896
# Found genres for Maz: ['melodic house']
#
# Processing track 710/1896
# Found genres for Pitbull: ['dance pop', 'miami hip hop', 'pop']
#
# Processing track 1312/1896
# Found genres for TommyMuzzic: ['sped up']
#
# Processing track 246/1896
# Found genres for Erdem Kınay: ['turkish pop']
#
# Processing track 1124/1896
# Found genres for Reckol: ['turkce drill', 'turkish hip hop']
#
# Processing track 975/1896
# Found genres for Alice DiMar: []
#
# Processing track 98/1896
# Found genres for Model: ['turkish pop', 'turkish rock']
#
# Processing track 774/1896
# Found genres for Daft Punk: ['electro', 'filter house', 'rock']
#
# Processing track 347/1896
# Found genres for Beyoncé: ['pop', 'r&b']
#
# Processing track 812/1896
# Found genres for Hayden James: ['aussietronica', 'gauze pop', 'house']
#
# Processing track 1681/1896
# Found genres for SR: ['uk drill']
#
# Processing track 1734/1896
# Found genres for Tazzy: []
#
# Processing track 1670/1896
# Found genres for Lil Uzi Vert: ['hip hop', 'melodic rap', 'philly rap', 'rage rap', 'rap', 'trap']
#
# Processing track 220/1896
# Found genres for Conte Prad: []
#
# Processing track 873/1896
# Found genres for Ciao Italia !: []
#
# Processing track 1432/1896
# Found genres for Clean Bandit: ['pop', 'uk dance', 'uk funky']
#
# Processing track 216/1896
# Found genres for Tribün Besteleri: ['new school turkce rap']
#
# Processing track 1509/1896
# Found genres for Chase Atlantic: ['alternative r&b']
#
# Processing track 519/1896
# Found genres for Portugal. The Man: ['indie rock', 'indietronica', 'modern alternative rock', 'modern rock']
#
# Processing track 1238/1896
# Found genres for cassö: ['hypertechno', 'pop dance']
#
# Processing track 415/1896
# Found genres for The Weeknd: ['canadian contemporary r&b', 'canadian pop', 'pop']
#
# Processing track 1275/1896
# Found genres for DA: ['atl hip hop', 'hip hop', 'rap', 'southern hip hop', 'trap']
#
# Processing track 1071/1896
# Found genres for The Living Tombstone: ['otacore', 'pixel', 'pov: indie']
#
# Processing track 716/1896
# Found genres for ANOTR: ['dutch tech house']
#
# Processing track 205/1896
# Found genres for Göksel: ['turkce slow sarkilar', 'turkish pop']
#
# Processing track 140/1896
# Found genres for Hande Yener: ['turkish pop']
#
# Processing track 1283/1896
# Found genres for Demet Akalın: ['turkish pop']
#
# Processing track 207/1896
# Found genres for Russ Millions: ['melodic drill', 'uk drill']
#
# Processing track 1019/1896
# Found genres for Hadise: ['turkish deep house', 'turkish pop']
#
# Processing track 1054/1896
# Found genres for Bad Bunny: ['reggaeton', 'trap latino', 'urbano latino']
#
# Processing track 1583/1896
# Found genres for Calvin Harris: ['dance pop', 'edm', 'electro house', 'house', 'pop', 'progressive house', 'uk dance']
#
# Processing track 1197/1896
# Found genres for Jones Meadow: ['chill beats']
#
# Processing track 91/1896
# Found genres for HUGEL: ['deep house']
#
# Processing track 1415/1896
# Found genres for Valante: []
#
# Processing track 236/1896
# Found genres for Katy Perry: ['pop']
#
# Processing track 57/1896
# Found genres for Distoboy: []
#
# Processing track 284/1896
# Found genres for ZHU: ['edm', 'electro house']
#
# Processing track 1242/1896
# Found genres for The Weeknd: ['canadian contemporary r&b', 'canadian pop', 'pop']
#
# Processing track 349/1896
# Found genres for Metro Boomin: ['rap']
#
# Processing track 1469/1896
# Found genres for Milky Chance: ['german pop', 'modern rock']
#
# Processing track 1521/1896
# Found genres for Duman: ['anadolu rock', 'karadeniz turkuleri', 'turkish alternative', 'turkish alternative rock', 'turkish rock']
#
# Processing track 1277/1896
# Found genres for Duke Dumont: ['edm', 'house', 'pop dance', 'progressive house', 'uk dance']
#
# Processing track 1335/1896
# Found genres for Twelwe: []
#
# Processing track 840/1896
# Found genres for Wegh: ['new school turkce rap']
#
# Processing track 1285/1896
# Found genres for The Weeknd: ['canadian contemporary r&b', 'canadian pop', 'pop']
#
# Processing track 1051/1896
# Found genres for HUGEL: ['deep house']
#
# Processing track 1657/1896
# Found genres for Lil Zey: ['turkce kadin rap', 'turkish hip hop', 'turkish trap']
#
# Processing track 197/1896
# Found genres for cakal: ['turkce drill']
#
# Processing track 591/1896
# Found genres for Daft Punk: ['dance pop', 'pop']
#
# Processing track 1072/1896
# Found genres for Calvin Harris: ['dance pop', 'edm', 'electro house', 'house', 'pop', 'progressive house', 'uk dance']
#
# Processing track 1235/1896
# Found genres for The Weeknd: ['canadian contemporary r&b', 'canadian pop', 'pop']
#
# Processing track 1678/1896
# Found genres for Charlie Puth: ['pop', 'viral pop']
#
# Processing track 390/1896
# Found genres for Cray Barnes: []
#
# Processing track 1730/1896
# Found genres for Aşkın Nur Yengi: ['turkish pop']
#
# ...
#
# Processing track 1307/1896
# Found genres for Mckyyy: ['sped up']
#
# Processing track 1830/1896
# Found genres for tana: ['bedroom r&b', 'hyperpop francais']
#
# Processing track 1254/1896
# Found genres for Endor: ['deep groove house', 'scottish rock']
#
# Processing track 1013/1896
# Found genres for Kali Uchis: ['colombian pop']
#
# Processing track 1015/1896
# Found genres for David Guetta: ['big room', 'dance pop', 'edm', 'pop', 'pop dance']
#
# Processing track 763/1896
# Found genres for Lana Del Rey: ['art pop', 'pop']
#
# Processing track 1895/1896
# Found genres for ooes: ['russian alt pop']
#
# Processing track 387/1896
# Found genres for Yosuf: ['gym hardstyle']
#
# Processing track 1/1896
# Found genres for Peggy Gou: ['electra', 'float house']
#
# Processing track 960/1896
# Found genres for SICK CVNT: []
#
# Processing track 1112/1896
# Found genres for Tobtok: ['deep tropical house', 'uk dance']
#
# Processing track 1264/1896
# Found genres for Aitch: ['manchester hip hop', 'uk hip hop']
#
# Processing track 1176/1896
# Found genres for Tribbs: ['polish pop', 'polish viral pop']
#
# Processing track 985/1896
# Found genres for JKRS: ['hypertechno']
#
# Processing track 388/1896
# Found genres for Le Tigre: ['dance-punk', 'queercore', 'riot grrrl']
#
# Processing track 38/1896
# Found genres for FloyyMenor: ['reggaeton chileno']
#
# Processing track 634/1896
# Found genres for Aynur Aydın: ['turkish pop']
#
# Processing track 913/1896
# Found genres for Young Zerka: ['albanian pop', 'basshall']
#
# Processing track 1605/1896
# Found genres for emriboi: []
#
# Processing track 921/1896
# Found genres for Shakira: ['colombian pop', 'dance pop', 'latin pop', 'pop']
#
# Processing track 1389/1896
# No results found for Sex, Drugs, Etc. - Speed by Ren
#
# Processing track 355/1896
# Found genres for Isolate.exe: ['drift phonk', 'gym phonk']
#
# Processing track 630/1896
# Found genres for Ayaz Erdoğan: ['turkish trap pop']
#
# Processing track 1325/1896
# Found genres for POSEIDON: ['gym hardstyle']
#
# Processing track 1390/1896
# Found genres for David Guetta: ['big room', 'dance pop', 'edm', 'pop', 'pop dance']
#
# Processing track 1563/1896
# Found genres for mxpheebz: ['ambient lo-fi']
#
# Processing track 572/1896
# Found genres for DJ Khaled: ['hip hop', 'miami hip hop', 'pop rap', 'rap']
#
# Processing track 108/1896
# Found genres for XXXTENTACION: ['emo rap', 'miami hip hop', 'rap']
#
# Processing track 973/1896
# Found genres for Blacha 2115: ['polish hip hop', 'polish trap']
#
# Processing track 79/1896
# Found genres for Tevvez: ['gym hardstyle']
#
# Processing track 1540/1896
# Found genres for Hozier: ['irish singer-songwriter', 'modern rock', 'pop', 'pov: indie']
#
# Processing track 584/1896
# Found genres for Khontkar: ['turkish hip hop', 'turkish trap']
#
# Processing track 534/1896
# Found genres for Clairo: ['bedroom pop', 'indie pop', 'pov: indie']
#
# Processing track 888/1896
# Found genres for Alex1: ['chill drill', 'melodic drill']
#
# Processing track 1032/1896
# Found genres for Tyler ICU: ['amapiano']
#
# Processing track 1014/1896
# Found genres for Conan Gray: ['bedroom pop', 'pop', 'pov: indie']
#
# Processing track 7/1896
# Found genres for Lvbel C5: ['turkce drill', 'turkish trap']
#
# Processing track 852/1896
# Found genres for Khontkar: ['turkish hip hop', 'turkish trap']
#
# Processing track 322/1896
# Found genres for CamelPhat: ['deep tech house', 'house', 'progressive house', 'uk dance']
#
# Processing track 1631/1896
# Found genres for Güldiyar Tanrıdağlı: []
#
# Processing track 358/1896
# Found genres for PlanBe: ['polish hip hop', 'polish trap']
#
# Processing track 46/1896
# Found genres for Ludacris: ['atl hip hop', 'dance pop', 'dirty south rap', 'hip hop', 'old school atlanta hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap']
#
# Processing track 547/1896
# Found genres for Mac DeMarco: ['edmonton indie', 'lo-fi indie', 'pov: indie', 'slacker rock']
#
# Processing track 1608/1896
# Found genres for Nori ty: []
#
# Processing track 1223/1896
# Found genres for Dystanze: []
#
# Processing track 1225/1896
# Found genres for Gentlemann-: []
#
# Processing track 1727/1896
# Found genres for Ajda Pekkan: ['turkish pop', 'turkish psych']
#
# Processing track 1558/1896
# Found genres for Sena Şener: ['turkish alt pop', 'turkish modern jazz', 'turkish rock']
#
# Processing track 565/1896
# Found genres for Lvbel C5: ['turkce drill', 'turkish trap']
#
# Processing track 503/1896
# Found genres for The Tech Thieves: ['dark r&b']
#
# Processing track 104/1896
# Found genres for Gorgon City: ['future garage', 'house', 'pop dance', 'uk dance']
#
# Processing track 174/1896
# Found genres for Gipsy Casual: []
#
# Processing track 144/1896
# Found genres for Ari Abdul: ['dark r&b', 'sped up']
#
# Processing track 626/1896
# Found genres for Lvbel C5: ['turkce drill', 'turkish trap']
#
# Processing track 729/1896
# Found genres for Jay Dunham: ['dark clubbing']
#
# Processing track 1784/1896
# Found genres for sped up viral: ['sped up']
#
# Processing track 1082/1896
# Found genres for frxzen: ['slowed and reverb']
#
# Processing track 1207/1896
# Found genres for Mina: ['classic italian pop', 'italian adult pop', 'ye ye']
#
# Processing track 451/1896
# Found genres for Aerosmith: ['album rock', 'classic rock', 'hard rock', 'rock']
#
# Processing track 993/1896
# Found genres for Future: ['atl hip hop', 'hip hop', 'rap', 'southern hip hop', 'trap']
#
# Processing track 771/1896
# Found genres for ZHU: ['edm', 'electro house']
#
# Processing track 915/1896
# Found genres for partywithray: []
#
# Processing track 1104/1896
# Found genres for INNA: ['dance pop', 'romanian house', 'romanian pop']
#
# Processing track 506/1896
# Found genres for Rod Wave: ['florida rap']
#
# Processing track 1722/1896
# Found genres for Cigarettes After Sex: ['ambient pop', 'dream pop', 'el paso indie', 'shoegaze']
#
# Processing track 1590/1896
# Found genres for Fly Project: ['romanian pop']
#
# Processing track 1025/1896
# Found genres for Shiva: ['italian hip hop', 'italian pop', 'trap italiana']
#
# Processing track 1343/1896
# Found genres for Capital Cities: ['metropopolis', 'modern rock']
#
# Processing track 1065/1896
# Found genres for Zerb: ['pop dance']
#
# Processing track 1083/1896
# Found genres for Reea: ['romanian house']
#
# Processing track 1315/1896
# Found genres for INNA: ['dance pop', 'romanian house', 'romanian pop']
#
# Processing track 1316/1896
# Found genres for Manu Chao: ['latin alternative', 'world']
#
# Processing track 725/1896
# Found genres for XXXTENTACION: ['emo rap', 'miami hip hop', 'rap']
#
# Processing track 1168/1896
# Found genres for Rihanna: ['barbadian pop', 'pop', 'urban contemporary']
#
# Processing track 823/1896
# Found genres for cakal: ['turkce drill']
#
# Processing track 189/1896
# Found genres for Genç Fenerbahçeliler: []
#
# Processing track 1358/1896
# Found genres for Duman: ['anadolu rock', 'karadeniz turkuleri', 'turkish alternative', 'turkish alternative rock', 'turkish rock']
#
# Processing track 1218/1896
# Found genres for Selena Gomez: ['pop', 'post-teen pop']
#
# Processing track 1041/1896
# Found genres for LXNGVX: ['gym phonk', 'krushfunk']
#
# Processing track 1838/1896
# Found genres for pearl: ['sped up']
#
# Processing track 601/1896
# Found genres for Guti: ['corecore']
#
# Processing track 440/1896
# Found genres for Just Kiddin: ['house', 'uk dance']
#
# Processing track 1092/1896
# Found genres for Dennis Lloyd: ['israeli pop']
#
# Processing track 1224/1896
# Found genres for League of Legends: ['speedrun', 'video game music']
#
# Processing track 1507/1896
# Found genres for Alan Walker: ['electro house']
#
# Processing track 232/1896
# Found genres for Nathan C: []
#
# Processing track 505/1896
# Found genres for Lithe: []
#
# Processing track 476/1896
# Found genres for Sky Rompiendo: ['trap latino', 'urbano latino']
#
# Processing track 1127/1896
# Found genres for Rich Amiri: ['rage rap']
#
# Processing track 1133/1896
# Found genres for Six Dior: ['sped up']
#
# Processing track 910/1896
# Found genres for RageMode: []
#
# Processing track 206/1896
# Found genres for KÖFN: ['turkish alt pop', 'turkish pop']
#
# Processing track 726/1896
# Found genres for Tion Wayne: ['london rap', 'uk hip hop']
#
# Processing track 1391/1896
# Found genres for Movements: ['uk drill']
#
# Processing track 1007/1896
# Found genres for Chase Atlantic: ['alternative r&b']
#
# Processing track 694/1896
# Found genres for Shakira: ['colombian pop', 'dance pop', 'latin pop', 'pop']
#
# Processing track 333/1896
# Found genres for Jorja Smith: ['r&b', 'uk contemporary r&b']
#
# Processing track 247/1896
# Found genres for Tanerélle: ['alternative r&b']
#
# Processing track 1231/1896
# Found genres for Brent Faiyaz: ['r&b', 'rap']
#
# Processing track 1258/1896
# Found genres for Arctic Monkeys: ['garage rock', 'modern rock', 'permanent wave', 'rock', 'sheffield indie']
#
# Processing track 222/1896
# Found genres for Calvin Harris: ['dance pop', 'edm', 'electro house', 'house', 'pop', 'progressive house', 'uk dance']
#
# Processing track 1366/1896
# Found genres for David Guetta: ['big room', 'dance pop', 'edm', 'pop', 'pop dance']
#
# Processing track 1542/1896
# Found genres for DRAY: []
#
# Processing track 767/1896
# Found genres for Shift K3Y: ['house', 'uk dance']
#
# Processing track 1240/1896
# Found genres for Kanye West: ['chicago rap', 'hip hop', 'rap']
#
# Processing track 751/1896
# Found genres for Tyga: ['hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap']
#
# Processing track 282/1896
# Found genres for DJ Tec: ['sped up']
#
# Processing track 764/1896
# Found genres for Dynoro: ['edm']
#
# Processing track 1482/1896
# Found genres for YA NINA: ['albanian pop']
#
# Processing track 893/1896
# Found genres for Ronzo: ['chill drill', 'melodic drill']
#
# Processing track 1250/1896
# Found genres for Don Toliver: ['rap']
#
# Processing track 826/1896
# Found genres for Ati242: ['turkish hip hop']
#
# Processing track 123/1896
# Found genres for Lil Uzi Vert: ['hip hop', 'melodic rap', 'philly rap', 'rage rap', 'rap', 'trap']
#
# Processing track 1888/1896
# Found genres for Gülben Ergen: ['arabesk', 'turkish pop']
#
# Processing track 566/1896
# Found genres for Ch3f Beats: []
#
# Processing track 683/1896
# Found genres for Röya: ['azeri pop']
#
# Processing track 1591/1896
# Found genres for Sak Noel: []
#
# Processing track 792/1896
# Found genres for cakal: ['turkce drill']
#
# Processing track 655/1896
# Found genres for Ellie Goulding: ['indietronica', 'metropopolis', 'pop', 'uk pop']
#
# Processing track 1493/1896
# Found genres for RÜFÜS DU SOL: ['australian electropop', 'indietronica']
#
# Processing track 1365/1896
# Found genres for WhyTek: []
#
# Processing track 23/1896
# Found genres for Central Cee: ['melodic drill', 'r&drill']
#
# Processing track 95/1896
# Found genres for Tom Odell: ['chill pop']
#
# Processing track 1592/1896
# Found genres for Kacper HTA: ['polish hip hop', 'rap uliczny']
#
# Processing track 1023/1896
# Found genres for JVLA: ['viral rap']
#
# Processing track 1128/1896
# Found genres for ZHU: ['edm', 'electro house']
#
# Processing track 360/1896
# Found genres for D38: []
#
# Processing track 1075/1896
# Found genres for Don Toliver: ['rap']
#
# Processing track 361/1896
# Found genres for Lvbel C5: ['turkce drill', 'turkish trap']
#
# Processing track 1567/1896
# Found genres for Duke Dumont: ['edm', 'house', 'pop dance', 'progressive house', 'uk dance']
#
# Processing track 1094/1896
# Found genres for JVLA: ['viral rap']
#
# Processing track 413/1896
# Found genres for Ice Spice: ['bronx drill']
#
# Processing track 96/1896
# Found genres for Ceylan: ['arabesk', 'turkish folk']
#
# Processing track 1037/1896
# Found genres for Canking: ['chill drill', 'melodic drill']
#
# Processing track 406/1896
# Found genres for Alex Gaudino: ['disco house', 'vocal house']
#
# Processing track 293/1896
# Found genres for Matt Simons: ['neo-singer-songwriter']
#
# Processing track 1449/1896
# Found genres for Metro Boomin: ['rap']
#
# Processing track 786/1896
# Found genres for фрози: ['sped up']
#
# Processing track 857/1896
# Found genres for Jakuzi: ['turkish alternative rock']
#
# Processing track 397/1896
# Found genres for Ebru Gündeş: ['arabesk', 'turkish folk', 'turkish pop']
#
# Processing track 1153/1896
# Found genres for Canking: ['chill drill', 'melodic drill']
#
# Processing track 328/1896
# Found genres for JBEE: ['chill drill', 'melodic drill']
#
# Processing track 946/1896
# Found genres for A-Wall: ['bedroom pop']
#
# Processing track 731/1896
# Found genres for Travis Scott: ['rap', 'slap house']
#
# Processing track 1150/1896
# Found genres for Bagatune: []
#
# Processing track 20/1896
# Found genres for Lil Tecca: ['melodic rap', 'pluggnb', 'rap']
#
# Processing track 999/1896
# Found genres for DTF: ['cloud rap francais', 'french hip hop', 'pop urbaine', 'rap conscient', 'rap francais']
#
# Processing track 1021/1896
# Found genres for J Balvin: ['reggaeton', 'reggaeton colombiano', 'trap latino', 'urbano latino']
#
# Processing track 393/1896
# Found genres for MIKOLAS: ['czech pop']
#
# Processing track 535/1896
# Found genres for Kanye West: ['chicago rap', 'hip hop', 'rap']
#
# Processing track 966/1896
# Found genres for S3BZS: ['phonk brasileiro']
#
# Processing track 1757/1896
# Found genres for Disclosure: ['edm', 'house', 'indietronica', 'uk dance']
#
# Processing track 461/1896
# Found genres for EDIS: ['turkish pop']
#
# Processing track 321/1896
# Found genres for sped up nightcore: ['nightcore', 'sped up']
#
# Processing track 756/1896
# Found genres for Gibran Alcocer: ['ambient lo-fi']
#
# Processing track 1817/1896
# Found genres for berlioz: ['jazz house']
#
# Processing track 1288/1896
# Found genres for ZHU: ['edm', 'electro house']
#
# Processing track 1087/1896
# Found genres for Mathame: ['italian techno']
#
# Processing track 638/1896
# Found genres for cakal: ['turkce drill']
#
# Processing track 253/1896
# Found genres for Kay Flock: ['bronx drill', 'melodic drill', 'new york drill']
#
# Processing track 1248/1896
# Found genres for CASAWI: []
#
# Processing track 418/1896
# Found genres for Banu Parlak: ['turkish pop', 'uzbek pop']
#
# Processing track 1181/1896
# Found genres for Lieselotte: []
#
# Processing track 1857/1896
# Found genres for Dream, Ivory: ['modern dream pop']
#
# Processing track 617/1896
# Found genres for Bastille: ['metropopolis', 'modern rock', 'pop']
#
# Processing track 1459/1896
# Found genres for Dave: ['uk hip hop']
#
# Processing track 938/1896
# Found genres for Two Feet: ['indie poptimism', 'modern rock']
#
# Processing track 173/1896
# Found genres for 21 Savage: ['atl hip hop', 'hip hop', 'rap']
#
# Processing track 1728/1896
# Found genres for KÖFN: ['turkish alt pop', 'turkish pop']
#
# Processing track 863/1896
# Found genres for Aydın Kurtoğlu: ['turkish pop']
#
# Processing track 1795/1896
# Found genres for SUICIDAL-IDOL: ['scenecore', 'sped up']
#
# Processing track 1702/1896
# Found genres for CJ: ['nyc rap']
#
# Processing track 1506/1896
# Found genres for The Temper Trap: ['indietronica', 'modern rock', 'shimmer pop']
#
# Processing track 92/1896
# Found genres for Amaarae: ['afro r&b', 'afrobeats', 'alternative r&b', 'ghanaian alternative', 'ghanaian pop']
#
# Processing track 854/1896
# Found genres for BL3SS: []
#
# Processing track 62/1896
# Found genres for KÖFN: ['turkish alt pop', 'turkish pop']
#
# Processing track 1715/1896
# Found genres for Duke Dumont: ['edm', 'house', 'pop dance', 'progressive house', 'uk dance']
#
# Processing track 404/1896
# Found genres for Bob Moses: ['canadian electronic', 'canadian house']
#
# Processing track 1334/1896
# Found genres for sped up nightcore: ['nightcore', 'sped up']
#
# Processing track 1035/1896
# Found genres for ZHU: ['edm', 'electro house']
#
# Processing track 533/1896
# Found genres for Mitski: ['brooklyn indie', 'pov: indie']
#
# Processing track 113/1896
# Found genres for EDIS: ['turkish pop']
#
# Processing track 1767/1896
# Found genres for Oğuzhan Koç: ['turkish pop']
#
# Processing track 1741/1896
# Found genres for İrem Derici: ['turkish pop']
#
# Processing track 972/1896
# Found genres for Murda: ['basshall', 'turkish hip hop', 'turkish trap']
#
# Processing track 1142/1896
# Found genres for Dj Rehan: []
#
# Processing track 1624/1896
# Found genres for Soft Sea: []
#
# Processing track 587/1896
# Found genres for Sezen Aksu: ['turkish pop']
#
# Processing track 42/1896
# Found genres for Travis Scott: ['rap', 'slap house']
#
# Processing track 512/1896
# Found genres for Mabel Matiz: ['turkish pop']
#
# Processing track 1399/1896
# Found genres for Ati242: ['turkish hip hop']
#
# Successfully processed 1570 tracks

# %%
# [Cell 1] - Import libraries and load data
import pandas as pd
import json
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import numpy as np

def analyze_genre_spending():
    # Load collected genre data
    with open('genre_progress.json', 'r', encoding='utf-8') as f:
        genre_data = json.load(f)
    
    # Create genre mapping
    genre_mapping = {
        (track['artist'], track['track']): track['genres']
        for track in genre_data
        if track['genres']
    }
    
    # Load streaming history
    with open('StreamingHistory_music_2.json', 'r', encoding='utf-8') as f:
        streaming_data = json.load(f)
    
    # Process streaming data
    streaming_df = pd.DataFrame(streaming_data)
    streaming_df['date'] = pd.to_datetime(streaming_df['endTime']).dt.date
    streaming_df['genres'] = streaming_df.apply(
        lambda row: genre_mapping.get((row['artistName'], row['trackName']), []),
        axis=1
    )
    
    # Explode genres
    genre_df = streaming_df.explode('genres')
    genre_df = genre_df[genre_df['genres'].notna()]
    
    # Calculate daily listening time per genre
    genre_daily = genre_df.groupby(['date', 'genres'])['msPlayed'].sum().reset_index()
    genre_daily['minutes_played'] = genre_daily['msPlayed'] / (1000 * 60)
    
    # Load spending data
    bank_df = pd.read_excel('HesapHareketleri_28.11.2024_0124383 (1).xlsx', 
                           skiprows=8,
                           names=['Date', 'Time', 'Amount', 'Balance', 'Description', 'Receipt'])
    
    bank_df = bank_df[bank_df['Date'].str.match(r'\d{2}\.\d{2}\.\d{4}', na=False)]
    bank_df['date'] = pd.to_datetime(bank_df['Date'], format='%d.%m.%Y').dt.date
    bank_df['Amount'] = pd.to_numeric(bank_df['Amount'], errors='coerce')
    
    # Merge data
    merged_df = pd.merge(genre_daily, bank_df[['date', 'Amount']], on='date', how='inner')
    
    # Calculate genre statistics
    genre_stats = []
    min_days = 5
    
    for genre in merged_df['genres'].unique():
        genre_data = merged_df[merged_df['genres'] == genre]
        if len(genre_data) >= min_days:
            correlation = genre_data['minutes_played'].corr(genre_data['Amount'])
            avg_spending = genre_data['Amount'].mean()
            total_minutes = genre_data['minutes_played'].sum()
            
            genre_stats.append({
                'genre': genre,
                'correlation': correlation,
                'avg_spending': avg_spending,
                'total_minutes': total_minutes,
                'days_counted': len(genre_data)
            })
    
    return pd.DataFrame(genre_stats)

def create_visualizations(genre_stats_df):
    # Sort and select top genres
    genre_stats_df['abs_correlation'] = abs(genre_stats_df['correlation'])
    top_genres = genre_stats_df.nlargest(15, 'total_minutes')
    
    # Create figure
    plt.style.use('default')
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 15))
    
    # Plot 1: Correlations
    corr_plot = sns.barplot(
        data=top_genres,
        x='correlation',
        y='genre',
        ax=ax1,
        palette='RdBu_r'
    )
    ax1.set_title('Genre-Spending Correlations\n(Top 15 Most Listened Genres)', fontsize=14)
    ax1.set_xlabel('Correlation Coefficient', fontsize=12)
    ax1.axvline(x=0, color='black', linestyle='-', alpha=0.2)
    
    # Add correlation values
    for i, v in enumerate(top_genres['correlation']):
        ax1.text(v, i, f'{v:.2f}', va='center', fontsize=10)
    
    # Plot 2: Average spending
    spend_plot = sns.barplot(
        data=top_genres,
        x='avg_spending',
        y='genre',
        ax=ax2,
        palette='viridis'
    )
    ax2.set_title('Average Daily Spending by Genre', fontsize=14)
    ax2.set_xlabel('Average Spending (TL)', fontsize=12)
    
    # Add spending values
    for i, v in enumerate(top_genres['avg_spending']):
        ax2.text(v, i, f'{v:,.0f} TL', va='center', fontsize=10)
    
    plt.tight_layout()
    return fig

def main():
    # Analyze data
    genre_stats = analyze_genre_spending()
    
    # Create visualizations
    fig = create_visualizations(genre_stats)
    plt.savefig('genre_spending_results.png', dpi=300, bbox_inches='tight')
    plt.close()
    
    # Print results
    print("\nTop 5 genres most positively correlated with spending:")
    print(genre_stats.nlargest(5, 'correlation')[['genre', 'correlation', 'avg_spending']].round(2))
    
    print("\nTop 5 genres most negatively correlated with spending:")
    print(genre_stats.nsmallest(5, 'correlation')[['genre', 'correlation', 'avg_spending']].round(2))
    
    print("\nGenres with highest average daily spending:")
    print(genre_stats.nlargest(5, 'avg_spending')[['genre', 'avg_spending', 'correlation']].round(2))

if __name__ == "__main__":
    main()
# Out:
# c:\Users\90507\anaconda3\envs\pandas\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# c:\Users\90507\anaconda3\envs\pandas\Lib\site-packages\numpy\lib\function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\90507\AppData\Local\Temp\ipykernel_13260\779891447.py:84: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   corr_plot = sns.barplot(
# C:\Users\90507\AppData\Local\Temp\ipykernel_13260\779891447.py:100: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   spend_plot = sns.barplot(
# Top 5 genres most positively correlated with spending:
#                 genre  correlation  avg_spending
# 178      austrian pop         1.00        603.23
# 275        mahraganat         1.00       -396.77
# 199      metropopolis         0.99        384.13
# 209  stomp and holler         0.99        384.13
# 82      trap italiana         0.80        157.79
#
# Top 5 genres most negatively correlated with spending:
#                genre  correlation  avg_spending
# 165  electronic trap        -0.94       -234.93
# 28     karadeniz pop        -0.74        789.64
# 266  dancehall queen        -0.72        724.33
# 267     uk dancehall        -0.72        724.33
# 0       albanian pop        -0.64       1556.17
#
# Genres with highest average daily spending:
#                  genre  avg_spending  correlation
# 240  christian hip hop       1928.57         0.26
# 261              grime       1606.50         0.60
# 262         london rap       1606.50         0.60
# 0         albanian pop       1556.17        -0.64
# 200   modern indie pop       1554.77         0.17
